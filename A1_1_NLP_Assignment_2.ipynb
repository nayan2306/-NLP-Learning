# %% [markdown]
# #CREATE USER DEFINED CORPUS.

# %% [markdown]
# To create a user-defined corpus from PDF, DOCX, plain-text, and website, you can use a Python library such as PyPDF2 for PDFs, python-docx for DOCX files, and requests and BeautifulSoup for web scraping.
#
# First, you'll need to install the necessary libraries.

# %%
# !pip install PyPDF2==2.12.1
# !pip install python-docx
# !pip install requests
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2==2.12.1
#   Downloading pypdf2-2.12.1-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from PyPDF2==2.12.1) (4.5.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.12.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 36.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from python-docx) (4.9.2)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=39d857d83cabef534317735e61f79c20e9bdc1e9097ed52464cc74cf1542f9fb
#   Stored in directory: /root/.cache/pip/wheels/32/b8/b2/c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4) (4.6.3)

# %% [markdown]
# ### Importing Library

# %%
import PyPDF2
import docx
import requests
from bs4 import BeautifulSoup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### PDF

# %%
# PDF
pdf_file = open('/content/drive/MyDrive/NLP/NLP_for_Corpus_Linguistics.pdf', 'rb')
pdf_reader = PyPDF2.PdfFileReader(pdf_file)
pdf_text = ''
for page in range(pdf_reader.numPages):
    pdf_text += pdf_reader.getPage(page).extractText()

# %% [markdown]
# ### DOCX

# %%
docx_file = docx.Document('/content/drive/MyDrive/NLP/A1_1_NLP_Assignment_1.docx')
docx_text = ''
for para in docx_file.paragraphs:
    docx_text += para.text

# %% [markdown]
# ### PLAIN TEXT FILE

# %%
with open('/content/drive/MyDrive/NLP/NLP.txt', 'r') as f:
    plain_text = f.read()

# %% [markdown]
# ### WEBSITE

# %%
url = 'https://en.wikipedia.org/wiki/Natural_language_processing'
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')
website_text = soup.get_text()

# %% [markdown]
# Once you've extracted the text from each file type, you can combine them into a single corpus by concatenating the strings together.

# %%
corpus = pdf_text + docx_text + plain_text + website_text

# %%
corpus
# Out:
# 'Natural Language Processing for Corpus Linguistics  \n \nElements in Corpus  Linguistics  \n \nCambridge University Press  \n \nJonathan Dunn  \nUniversity of Canterbury  \n \nAbstract . Corpus analysis can be expanded and scaled up by incorporating computational \nmethods from natural language processing. This Element shows how text classification and text \nsimilarity models can extend our ability to undertake corpus linguistics across very large \ncorpora. These computational methods are be coming increasingly important as corpora grow \ntoo large for more traditional types of linguistic analysis. We draw on five case studies to show  \nhow and why to use computational methods, ranging from usage -based grammar to authorship \nanalysis to using soci al media for corpus -based sociolinguistics. Each section is accompanied by \nan interactive code notebook that shows how to implement the analysis in Python. A stand -\nalone Python package is also available to help readers use these methods with their own data . \nBecause large -scale analysis introduces new ethical problems, this Element pairs each new \nmethodology with a discussion of potential ethical implications.  \n \nBook : https://doi.org/10.1017/9781009070447   \nInteractivate Notebooks : https://doi.org/10 .24433/CO.3402613.v1   \nPython Package : https://github.com/jonathandunn/text_analytics   \n \n  Table of Contents  \n1. Computational Linguistic Analysis  \n1.1. Scaling Up Corpus Linguistics  \n1.2. The Case Studies  \n1.3. Categorization Problems  \n1.4. Comparison Problems  \n1.5. Language in Vector Space  \n1.6. Ethics: Data Rights  \n2. Text Classification  \n2.1. Evaluating Classifiers  \n2.2. Representing Content  \n2.3. Representing Structure  \n2.4. Representing Context  \n2.5. Representing Sentiment  \n2.6. Logistic Regression  \n2.7. Feed -Forward Networks  \n2.8. Ethics: Implicit Bias  \n3. Text Similarity  \n3.1. Categorization and Cognition  \n3.2. Measuring Corpus Similarity  \n3.3. Measuring Document Similarity  \n3.4. Measuring Word Similarity Using Association  \n3.5. Measuring Word Similarity in Vector Space  \n3.6. Clustering by Similarit y \n3.7. Ethics: Model Discrimination  \n4. Validation and Visualization  \n4.1. Reporting Results for Political Speech Prediction  \n4.2. Ensuring Validity Using Box Plots  \n4.3. Unmasking Pseudonymous Authors Using Line Plots  \n4.4. Comparing Word Embeddings Using Heat Maps  \n4.5. Following Linguistic Diversity Using Choropleth Maps  \n4.6. Ethics: Equal Access  \n5. Conclusions  \n  1.1 Scaling Up Corpus Linguistics  \nCorpus linguistics has entered a golden age, driven by both the amount and the range of \nlanguage that is now available for linguistic analysis. Corpus data is able to represent a \npopulation\'s usage at scale, by -passing the limitations which made introspect ion so important in \nthe 1950s. But this wide availability of language data requires that linguists have the methods \navailable to analyze it. And while there has been a surge of advances in natural language \nprocessing and computational linguistics, these ad vances have become increasingly \ndisconnected from corpus linguistics and linguistic theory. This Element brings natural \nlanguage processing and corpus linguistics together, showing how computational models can be \nused to answer both categorization  and comparison  problems. These computational models \nare presented using five case studies that will be introduced in the next section, ranging from \nsyntactic analysis to register analysis to corpus -based sociolinguistics.  \nThe goal here is to sh ow how to use these computational models, what linguistic questions they \ncan answer, and why it is important to scale up corpus linguistics in this way. A linguist can use \nthis Element to learn how to use natural language processing to answer linguistic qu estions \nthey are already familiar with. And a computer scientist can use this Element to learn about the \nling ...

# %% [markdown]
# ### Line, space, word, tweet tokenization on created corpus.
#
#
#
# *  The line_tokens variable will contain a
# list of sentences in the corpus.
# *  The space_tokens variable will contain a list of words separated by spaces.
# *   The word_tokens variable will contain a list of words.
# *   The tweet_tokens variable will contain a list of words and symbols that are commonly used in tweets.

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)

# %% [markdown]
# ### IMPORTING LIBRARY

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Tokenizer

# %% [markdown]
# ### Line tokenization

# %%
line_tokens = nltk.tokenize.sent_tokenize(corpus)
print(line_tokens)
# Out:
# ['Natural Language Processing for Corpus Linguistics  \n \nElements in Corpus  Linguistics  \n \nCambridge University Press  \n \nJonathan Dunn  \nUniversity of Canterbury  \n \nAbstract .', 'Corpus analysis can be expanded and scaled up by incorporating computational \nmethods from natural language processing.', 'This Element shows how text classification and text \nsimilarity models can extend our ability to undertake corpus linguistics across very large \ncorpora.', 'These computational methods are be coming increasingly important as corpora grow \ntoo large for more traditional types of linguistic analysis.', 'We draw on five case studies to show  \nhow and why to use computational methods, ranging from usage -based grammar to authorship \nanalysis to using soci al media for corpus -based sociolinguistics.', 'Each section is accompanied by \nan interactive code notebook that shows how to implement the analysis in Python.', 'A stand -\nalone Python package is also available to help readers use these methods with their own data .', 'Because large -scale analysis introduces new ethical problems, this Element pairs each new \nmethodology with a discussion of potential ethical implications.', 'Book : https://doi.org/10.1017/9781009070447   \nInteractivate Notebooks : https://doi.org/10 .24433/CO.3402613.v1   \nPython Package : https://github.com/jonathandunn/text_analytics   \n \n  Table of Contents  \n1.', 'Computational Linguistic Analysis  \n1.1.', 'Scaling Up Corpus Linguistics  \n1.2.', 'The Case Studies  \n1.3.', 'Categorization Problems  \n1.4.', 'Comparison Problems  \n1.5.', 'Language in Vector Space  \n1.6.', 'Ethics: Data Rights  \n2.', 'Text Classification  \n2.1.', 'Evaluating Classifiers  \n2.2.', 'Representing Content  \n2.3.', 'Representing Structure  \n2.4.', 'Representing Context  \n2.5.', 'Representing Sentiment  \n2.6.', 'Logistic Regression  \n2.7.', 'Feed -Forward Networks  \n2.8.', 'Ethics: Implicit Bias  \n3.', 'Text Similarity  \n3.1.', 'Categorization and Cognition  \n3.2.', 'Measuring Corpus Similarity  \n3.3.', 'Measuring Document Similarity  \n3.4.', 'Measuring Word Similarity Using Association  \n3.5.', 'Measuring Word Similarity in Vector Space  \n3.6.', 'Clustering by Similarit y \n3.7.', 'Ethics: Model Discrimination  \n4.', 'Validation and Visualization  \n4.1.', 'Reporting Results for Political Speech Prediction  \n4.2.', 'Ensuring Validity Using Box Plots  \n4.3.', 'Unmasking Pseudonymous Authors Using Line Plots  \n4.4.', 'Comparing Word Embeddings Using Heat Maps  \n4.5.', 'Following Linguistic Diversity Using Choropleth Maps  \n4.6.', 'Ethics: Equal Access  \n5.', 'Conclusions  \n  1.1 Scaling Up Corpus Linguistics  \nCorpus linguistics has entered a golden age, driven by both the amount and the range of \nlanguage that is now available for linguistic analysis.', "Corpus data is able to represent a \npopulation's usage at scale, by -passing the limitations which made introspect ion so important in \nthe 1950s.", 'But this wide availability of language data requires that linguists have the methods \navailable to analyze it.', 'And while there has been a surge of advances in natural language \nprocessing and computational linguistics, these ad vances have become increasingly \ndisconnected from corpus linguistics and linguistic theory.', 'This Element brings natural \nlanguage processing and corpus linguistics together, showing how computational models can be \nused to answer both categorization  and comparison  problems.', 'These computational models \nare presented using five case studies that will be introduced in the next section, ranging from \nsyntactic analysis to register analysis to corpus -based sociolinguistics.', 'The goal here is to sh ow how to use these computational models, what linguistic questions they \ncan answer, and why it is important to scale up corpus linguistics in this way.', 'A linguist can use \nthis Element to learn how to use natural language processing to answ ...

# %% [markdown]
# ### Space tokenization

# %%
space_tokens = corpus.split()
print(space_tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'for', 'Corpus', 'Linguistics', 'Elements', 'in', 'Corpus', 'Linguistics', 'Cambridge', 'University', 'Press', 'Jonathan', 'Dunn', 'University', 'of', 'Canterbury', 'Abstract', '.', 'Corpus', 'analysis', 'can', 'be', 'expanded', 'and', 'scaled', 'up', 'by', 'incorporating', 'computational', 'methods', 'from', 'natural', 'language', 'processing.', 'This', 'Element', 'shows', 'how', 'text', 'classification', 'and', 'text', 'similarity', 'models', 'can', 'extend', 'our', 'ability', 'to', 'undertake', 'corpus', 'linguistics', 'across', 'very', 'large', 'corpora.', 'These', 'computational', 'methods', 'are', 'be', 'coming', 'increasingly', 'important', 'as', 'corpora', 'grow', 'too', 'large', 'for', 'more', 'traditional', 'types', 'of', 'linguistic', 'analysis.', 'We', 'draw', 'on', 'five', 'case', 'studies', 'to', 'show', 'how', 'and', 'why', 'to', 'use', 'computational', 'methods,', 'ranging', 'from', 'usage', '-based', 'grammar', 'to', 'authorship', 'analysis', 'to', 'using', 'soci', 'al', 'media', 'for', 'corpus', '-based', 'sociolinguistics.', 'Each', 'section', 'is', 'accompanied', 'by', 'an', 'interactive', 'code', 'notebook', 'that', 'shows', 'how', 'to', 'implement', 'the', 'analysis', 'in', 'Python.', 'A', 'stand', '-', 'alone', 'Python', 'package', 'is', 'also', 'available', 'to', 'help', 'readers', 'use', 'these', 'methods', 'with', 'their', 'own', 'data', '.', 'Because', 'large', '-scale', 'analysis', 'introduces', 'new', 'ethical', 'problems,', 'this', 'Element', 'pairs', 'each', 'new', 'methodology', 'with', 'a', 'discussion', 'of', 'potential', 'ethical', 'implications.', 'Book', ':', 'https://doi.org/10.1017/9781009070447', 'Interactivate', 'Notebooks', ':', 'https://doi.org/10', '.24433/CO.3402613.v1', 'Python', 'Package', ':', 'https://github.com/jonathandunn/text_analytics', 'Table', 'of', 'Contents', '1.', 'Computational', 'Linguistic', 'Analysis', '1.1.', 'Scaling', 'Up', 'Corpus', 'Linguistics', '1.2.', 'The', 'Case', 'Studies', '1.3.', 'Categorization', 'Problems', '1.4.', 'Comparison', 'Problems', '1.5.', 'Language', 'in', 'Vector', 'Space', '1.6.', 'Ethics:', 'Data', 'Rights', '2.', 'Text', 'Classification', '2.1.', 'Evaluating', 'Classifiers', '2.2.', 'Representing', 'Content', '2.3.', 'Representing', 'Structure', '2.4.', 'Representing', 'Context', '2.5.', 'Representing', 'Sentiment', '2.6.', 'Logistic', 'Regression', '2.7.', 'Feed', '-Forward', 'Networks', '2.8.', 'Ethics:', 'Implicit', 'Bias', '3.', 'Text', 'Similarity', '3.1.', 'Categorization', 'and', 'Cognition', '3.2.', 'Measuring', 'Corpus', 'Similarity', '3.3.', 'Measuring', 'Document', 'Similarity', '3.4.', 'Measuring', 'Word', 'Similarity', 'Using', 'Association', '3.5.', 'Measuring', 'Word', 'Similarity', 'in', 'Vector', 'Space', '3.6.', 'Clustering', 'by', 'Similarit', 'y', '3.7.', 'Ethics:', 'Model', 'Discrimination', '4.', 'Validation', 'and', 'Visualization', '4.1.', 'Reporting', 'Results', 'for', 'Political', 'Speech', 'Prediction', '4.2.', 'Ensuring', 'Validity', 'Using', 'Box', 'Plots', '4.3.', 'Unmasking', 'Pseudonymous', 'Authors', 'Using', 'Line', 'Plots', '4.4.', 'Comparing', 'Word', 'Embeddings', 'Using', 'Heat', 'Maps', '4.5.', 'Following', 'Linguistic', 'Diversity', 'Using', 'Choropleth', 'Maps', '4.6.', 'Ethics:', 'Equal', 'Access', '5.', 'Conclusions', '1.1', 'Scaling', 'Up', 'Corpus', 'Linguistics', 'Corpus', 'linguistics', 'has', 'entered', 'a', 'golden', 'age,', 'driven', 'by', 'both', 'the', 'amount', 'and', 'the', 'range', 'of', 'language', 'that', 'is', 'now', 'available', 'for', 'linguistic', 'analysis.', 'Corpus', 'data', 'is', 'able', 'to', 'represent', 'a', "population's", 'usage', 'at', 'scale,', 'by', '-passing', 'the', 'limitations', 'which', 'made', 'introspect', 'ion', 'so', 'important', 'in', 'the', '1950s.', 'But', 'this', 'wide', 'availability', 'of', 'language', 'data', 'requires', 'that', 'linguists', 'have', 'the', 'methods', 'available', 'to', 'analyze', 'it.', 'And', ' ...

# %% [markdown]
# ### Word tokenization

# %%
word_tokens = nltk.tokenize.word_tokenize(corpus)

# %% [markdown]
# ### Tweet tokenization

# %%
tweet_tokens = nltk.tokenize.casual.TweetTokenizer().tokenize(corpus)
print(tweet_tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'for', 'Corpus', 'Linguistics', 'Elements', 'in', 'Corpus', 'Linguistics', 'Cambridge', 'University', 'Press', 'Jonathan', 'Dunn', 'University', 'of', 'Canterbury', 'Abstract', '.', 'Corpus', 'analysis', 'can', 'be', 'expanded', 'and', 'scaled', 'up', 'by', 'incorporating', 'computational', 'methods', 'from', 'natural', 'language', 'processing', '.', 'This', 'Element', 'shows', 'how', 'text', 'classification', 'and', 'text', 'similarity', 'models', 'can', 'extend', 'our', 'ability', 'to', 'undertake', 'corpus', 'linguistics', 'across', 'very', 'large', 'corpora', '.', 'These', 'computational', 'methods', 'are', 'be', 'coming', 'increasingly', 'important', 'as', 'corpora', 'grow', 'too', 'large', 'for', 'more', 'traditional', 'types', 'of', 'linguistic', 'analysis', '.', 'We', 'draw', 'on', 'five', 'case', 'studies', 'to', 'show', 'how', 'and', 'why', 'to', 'use', 'computational', 'methods', ',', 'ranging', 'from', 'usage', '-', 'based', 'grammar', 'to', 'authorship', 'analysis', 'to', 'using', 'soci', 'al', 'media', 'for', 'corpus', '-', 'based', 'sociolinguistics', '.', 'Each', 'section', 'is', 'accompanied', 'by', 'an', 'interactive', 'code', 'notebook', 'that', 'shows', 'how', 'to', 'implement', 'the', 'analysis', 'in', 'Python', '.', 'A', 'stand', '-', 'alone', 'Python', 'package', 'is', 'also', 'available', 'to', 'help', 'readers', 'use', 'these', 'methods', 'with', 'their', 'own', 'data', '.', 'Because', 'large', '-', 'scale', 'analysis', 'introduces', 'new', 'ethical', 'problems', ',', 'this', 'Element', 'pairs', 'each', 'new', 'methodology', 'with', 'a', 'discussion', 'of', 'potential', 'ethical', 'implications', '.', 'Book', ':', 'https://doi.org/10.1017/9781009070447', 'Interactivate', 'Notebooks', ':', 'https://doi.org/10', '.', '24433', '/', 'CO', '.', '3402613', '.', 'v1', 'Python', 'Package', ':', 'https://github.com/jonathandunn/text_analytics', 'Table', 'of', 'Contents', '1', '.', 'Computational', 'Linguistic', 'Analysis', '1.1', '.', 'Scaling', 'Up', 'Corpus', 'Linguistics', '1.2', '.', 'The', 'Case', 'Studies', '1.3', '.', 'Categorization', 'Problems', '1.4', '.', 'Comparison', 'Problems', '1.5', '.', 'Language', 'in', 'Vector', 'Space', '1.6', '.', 'Ethics', ':', 'Data', 'Rights', '2', '.', 'Text', 'Classification', '2.1', '.', 'Evaluating', 'Classifiers', '2.2', '.', 'Representing', 'Content', '2.3', '.', 'Representing', 'Structure', '2.4', '.', 'Representing', 'Context', '2.5', '.', 'Representing', 'Sentiment', '2.6', '.', 'Logistic', 'Regression', '2.7', '.', 'Feed', '-', 'Forward', 'Networks', '2.8', '.', 'Ethics', ':', 'Implicit', 'Bias', '3', '.', 'Text', 'Similarity', '3.1', '.', 'Categorization', 'and', 'Cognition', '3.2', '.', 'Measuring', 'Corpus', 'Similarity', '3.3', '.', 'Measuring', 'Document', 'Similarity', '3.4', '.', 'Measuring', 'Word', 'Similarity', 'Using', 'Association', '3.5', '.', 'Measuring', 'Word', 'Similarity', 'in', 'Vector', 'Space', '3.6', '.', 'Clustering', 'by', 'Similarit', 'y', '3.7', '.', 'Ethics', ':', 'Model', 'Discrimination', '4', '.', 'Validation', 'and', 'Visualization', '4.1', '.', 'Reporting', 'Results', 'for', 'Political', 'Speech', 'Prediction', '4.2', '.', 'Ensuring', 'Validity', 'Using', 'Box', 'Plots', '4.3', '.', 'Unmasking', 'Pseudonymous', 'Authors', 'Using', 'Line', 'Plots', '4.4', '.', 'Comparing', 'Word', 'Embeddings', 'Using', 'Heat', 'Maps', '4.5', '.', 'Following', 'Linguistic', 'Diversity', 'Using', 'Choropleth', 'Maps', '4.6', '.', 'Ethics', ':', 'Equal', 'Access', '5', '.', 'Conclusions', '1.1', 'Scaling', 'Up', 'Corpus', 'Linguistics', 'Corpus', 'linguistics', 'has', 'entered', 'a', 'golden', 'age', ',', 'driven', 'by', 'both', 'the', 'amount', 'and', 'the', 'range', 'of', 'language', 'that', 'is', 'now', 'available', 'for', 'linguistic', 'analysis', '.', 'Corpus', 'data', 'is', 'able', 'to', 'represent', 'a', "population's", 'usage', 'at', 'scale', ',', 'by', '-', 'passing', 'the', 'limitations', 'which', 'mad ...

# %% [markdown]
# #Perform stemming using porter stemmer on created corpus.

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
# Create an instance of the Porter stemmer
stemmer = PorterStemmer()

# %%
stemmed_corpus = []
for sentence in line_tokens:
    stemmed_sentence = [stemmer.stem(word) for word in sentence.split()]
    stemmed_corpus.append(" ".join(stemmed_sentence))

# %%
print(stemmed_corpus)
# Out:
# ['natur languag process for corpu linguist element in corpu linguist cambridg univers press jonathan dunn univers of canterburi abstract .', 'corpu analysi can be expand and scale up by incorpor comput method from natur languag processing.', 'thi element show how text classif and text similar model can extend our abil to undertak corpu linguist across veri larg corpora.', 'these comput method are be come increasingli import as corpora grow too larg for more tradit type of linguist analysis.', 'we draw on five case studi to show how and whi to use comput methods, rang from usag -base grammar to authorship analysi to use soci al media for corpu -base sociolinguistics.', 'each section is accompani by an interact code notebook that show how to implement the analysi in python.', 'a stand - alon python packag is also avail to help reader use these method with their own data .', 'becaus larg -scale analysi introduc new ethic problems, thi element pair each new methodolog with a discuss of potenti ethic implications.', 'book : https://doi.org/10.1017/9781009070447 interactiv notebook : https://doi.org/10 .24433/co.3402613.v1 python packag : https://github.com/jonathandunn/text_analyt tabl of content 1.', 'comput linguist analysi 1.1.', 'scale up corpu linguist 1.2.', 'the case studi 1.3.', 'categor problem 1.4.', 'comparison problem 1.5.', 'languag in vector space 1.6.', 'ethics: data right 2.', 'text classif 2.1.', 'evalu classifi 2.2.', 'repres content 2.3.', 'repres structur 2.4.', 'repres context 2.5.', 'repres sentiment 2.6.', 'logist regress 2.7.', 'feed -forward network 2.8.', 'ethics: implicit bia 3.', 'text similar 3.1.', 'categor and cognit 3.2.', 'measur corpu similar 3.3.', 'measur document similar 3.4.', 'measur word similar use associ 3.5.', 'measur word similar in vector space 3.6.', 'cluster by similarit y 3.7.', 'ethics: model discrimin 4.', 'valid and visual 4.1.', 'report result for polit speech predict 4.2.', 'ensur valid use box plot 4.3.', 'unmask pseudonym author use line plot 4.4.', 'compar word embed use heat map 4.5.', 'follow linguist divers use choropleth map 4.6.', 'ethics: equal access 5.', 'conclus 1.1 scale up corpu linguist corpu linguist ha enter a golden age, driven by both the amount and the rang of languag that is now avail for linguist analysis.', "corpu data is abl to repres a population' usag at scale, by -pass the limit which made introspect ion so import in the 1950s.", 'but thi wide avail of languag data requir that linguist have the method avail to analyz it.', 'and while there ha been a surg of advanc in natur languag process and comput linguistics, these ad vanc have becom increasingli disconnect from corpu linguist and linguist theory.', 'thi element bring natur languag process and corpu linguist together, show how comput model can be use to answer both categor and comparison problems.', 'these comput model are present use five case studi that will be introduc in the next section, rang from syntact analysi to regist analysi to corpu -base sociolinguistics.', 'the goal here is to sh ow how to use these comput models, what linguist question they can answer, and whi it is import to scale up corpu linguist in thi way.', 'a linguist can use thi element to learn how to use natur languag process to answer linguist qu estion they are alreadi familiar with.', 'and a comput scientist can use thi element to learn about the linguist assumpt and limit behind comput methods, matter that are too often disregard within natur languag process itself.', 'a categor problem is about assign a pre -defin label to some piec of language.', 'at the word level, thi could involv ask whether a particular open -class word is a noun or a verb.', 'at the sentenc level, thi could be ask what kind of con truction a particular sentenc represents.', 'at the document level, thi could be ask whether a particular speaker repres new zealand english or australian english.', 'all of these question can be answer use a text classif ...

# %% [markdown]
# Note that stemming is a lossy process, so stemmed words may not always be valid words in the language.

# %% [markdown]
# # Perform lemmatization using wordnet

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Create an instance of the WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Perform lemmatization on each word in the corpus
lemmatized_corpus = []
for sentence in line_tokens:
    lemmatized_sentence = [lemmatizer.lemmatize(word) for word in word_tokenize(sentence)]
    lemmatized_corpus.append(" ".join(lemmatized_sentence))

# %%
lemmatized_corpus = []
for sentence in line_tokens:
    tokenized_sentence = word_tokenize(sentence)
    lemmatized_sentence = [lemmatizer.lemmatize(word) for word in tokenized_sentence]
    lemmatized_corpus.append(" ".join(lemmatized_sentence))

# %%
print(lemmatized_corpus)
# Out:
# ['Natural Language Processing for Corpus Linguistics Elements in Corpus Linguistics Cambridge University Press Jonathan Dunn University of Canterbury Abstract .', 'Corpus analysis can be expanded and scaled up by incorporating computational method from natural language processing .', 'This Element show how text classification and text similarity model can extend our ability to undertake corpus linguistics across very large corpus .', 'These computational method are be coming increasingly important a corpus grow too large for more traditional type of linguistic analysis .', 'We draw on five case study to show how and why to use computational method , ranging from usage -based grammar to authorship analysis to using soci al medium for corpus -based sociolinguistics .', 'Each section is accompanied by an interactive code notebook that show how to implement the analysis in Python .', 'A stand - alone Python package is also available to help reader use these method with their own data .', 'Because large -scale analysis introduces new ethical problem , this Element pair each new methodology with a discussion of potential ethical implication .', 'Book : http : //doi.org/10.1017/9781009070447 Interactivate Notebooks : http : //doi.org/10 .24433/CO.3402613.v1 Python Package : http : //github.com/jonathandunn/text_analytics Table of Contents 1 .', 'Computational Linguistic Analysis 1.1 .', 'Scaling Up Corpus Linguistics 1.2 .', 'The Case Studies 1.3 .', 'Categorization Problems 1.4 .', 'Comparison Problems 1.5 .', 'Language in Vector Space 1.6 .', 'Ethics : Data Rights 2 .', 'Text Classification 2.1 .', 'Evaluating Classifiers 2.2 .', 'Representing Content 2.3 .', 'Representing Structure 2.4 .', 'Representing Context 2.5 .', 'Representing Sentiment 2.6 .', 'Logistic Regression 2.7 .', 'Feed -Forward Networks 2.8 .', 'Ethics : Implicit Bias 3 .', 'Text Similarity 3.1 .', 'Categorization and Cognition 3.2 .', 'Measuring Corpus Similarity 3.3 .', 'Measuring Document Similarity 3.4 .', 'Measuring Word Similarity Using Association 3.5 .', 'Measuring Word Similarity in Vector Space 3.6 .', 'Clustering by Similarit y 3.7 .', 'Ethics : Model Discrimination 4 .', 'Validation and Visualization 4.1 .', 'Reporting Results for Political Speech Prediction 4.2 .', 'Ensuring Validity Using Box Plots 4.3 .', 'Unmasking Pseudonymous Authors Using Line Plots 4.4 .', 'Comparing Word Embeddings Using Heat Maps 4.5 .', 'Following Linguistic Diversity Using Choropleth Maps 4.6 .', 'Ethics : Equal Access 5 .', 'Conclusions 1.1 Scaling Up Corpus Linguistics Corpus linguistics ha entered a golden age , driven by both the amount and the range of language that is now available for linguistic analysis .', "Corpus data is able to represent a population 's usage at scale , by -passing the limitation which made introspect ion so important in the 1950s .", 'But this wide availability of language data requires that linguist have the method available to analyze it .', 'And while there ha been a surge of advance in natural language processing and computational linguistics , these ad vances have become increasingly disconnected from corpus linguistics and linguistic theory .', 'This Element brings natural language processing and corpus linguistics together , showing how computational model can be used to answer both categorization and comparison problem .', 'These computational model are presented using five case study that will be introduced in the next section , ranging from syntactic analysis to register analysis to corpus -based sociolinguistics .', 'The goal here is to sh ow how to use these computational model , what linguistic question they can answer , and why it is important to scale up corpus linguistics in this way .', 'A linguist can use this Element to learn how to use natural language processing to answer linguistic qu estions they are already familiar with .', 'And a computer scientist can use this Element to learn about the linguistic assumption and limitat ...

# %%
lemmatized_sentence = [lemmatizer.lemmatize(word, pos='v') for word in tokenized_sentence]
print(lemmatized_sentence)
# Out:
# ["'", ')', ';', 'av_is_signed_in', '=', 'true', ';', '//', 'Call', 'user_logged_in_functions', 'user_logged_in', '(', 'user', ')', ';', '}', ')', '.catch', '(', 'function', '(', 'err', ')', '{', '//', 'If', 'user', 'be', 'NOT', 'log', 'in', '//console.log', '(', "'Logged", 'out', "'", ')', ';', '//', 'Logout', 'User', 'in', 'case', 'of', 'auth', 'faluire', 'if', '(', 'av_is_signed_in==false', ')', '{', 'user_logged_out', '(', ')', ';', '//', 'Enable', 'Login', 'Popup', '/', '*', 'if', '(', 'get_cookie', '(', "'avsignup", "'", ')', '===false', ')', '{', 'setTimeout', '(', 'function', '(', ')', '{', '$', '(', "'", '#', 'loginModal', "'", ')', '.modal', '(', ')', ';', '}', ',', '5000', ')', ';', '}', '*', '/', '}', '//user_logged_out', '(', ')', ';', 'google.accounts.id.prompt', '(', ')', ';', 'mgr.signinSilent', '(', ')', '.then', '(', 'function', '(', 'user', ')', '{', 'av_is_signed_in', '=', 'true', ';', '//console.log', '(', '``', 'silent', 'sign', 'in', "''", ',', 'user', ')', ';', 'user_logged_in', '(', 'user', ')', ';', '}', ')', '.catch', '(', 'function', '(', 'err', ')', '{', '//', 'Check', 'If', 'User', 'log', 'in', 'With', 'Google', 'Signon', 'av_is_signed_in', '=', 'false', ';', '//user_logged_out', '(', ')', ';', 'google.accounts.id.prompt', '(', ')', ';', 'console.log', '(', '``', 'Silentsignin', 'Err', "''", ')', ';', 'if', '(', 'get_cookie', '(', "'avsignup", "'", ')', '===false', ')', '{', 'setTimeout', '(', 'function', '(', ')', '{', '$', '(', "'", '#', 'loginModal', "'", ')', '.modal', '(', ')', ';', '}', ',', '5000', ')', ';', '}', '//console.log', '(', 'err', ')', ';', '}', ')', ';', '}', ')', ';', '}', '}', ')', '.catch', '(', 'function', '(', 'err', ')', '{', '//console.log', '(', "'Couldnt", 'get', 'user', "'", ')', ';', '//user_logged_out', '(', ')', ';', '//', 'Logout', 'User', 'in', 'case', 'of', 'auth', 'faluire', 'if', '(', 'av_is_signed_in==false', ')', '{', 'user_logged_out', '(', ')', ';', '//setTimeout', '(', 'function', '(', ')', '{', '$', '(', "'", '#', 'loginModal', "'", ')', '.modal', '(', ')', ';', '}', ',', '5000', ')', ';', '}', '}', ')', ';', '//', 'Modal', 'Skip', '$', '(', "'", '#', 'signup-modal-skip', "'", ')', '.click', '(', 'function', '(', ')', '{', 'document.cookie', '=', '``', 'avsignup=yes', ';', 'expires=Mon', ',', '30', 'Jan', '2023', '05:06:07', 'UTC', ';', 'path=/', "''", ';', '}', ')', ';', '}', ')', ';', '//', 'document.ready', '//', 'For', 'Google', 'Sign', 'On', 'function', 'handleCredentialResponse', '(', 'callback_data', ')', '{', '//', 'get', 'credentials', 'from', 'google', 'and', 'send', 'it', 'for', 'login', 'callback_data', '[', "'source_platform", "'", ']', "='blogs-prod", "'", ';', 'callback_data', '[', "'redirect_url", "'", ']', '=', 'window.location.href', ';', "//'https", ':', '//www.analyticsvidhya.com/', "'", ';', 'callback_data', '[', "'url", "'", ']', '=', 'window.location.href', ';', 'callback_data', '[', "'button_id", "'", ']', '=', '1113', ';', '$', '.ajax', '(', '{', 'url', ':', "''", 'https', ':', '//id.analyticsvidhya.com/automation/google/onetap/blog/login', "''", ',', 'data', ':', 'callback_data', ',', 'method', ':', "'post", "'", ',', 'success', ':', 'function', '(', 'response', ')', '{', '//console.log', '(', 'response', ')', 'payload', '=', 'JSON.parse', '(', 'response', ')', 'av_is_signed_in', '=', 'true', ';', '//', 'console.log', '(', 'payload', ')', ';', '//', 'console.log', '(', 'payload.identityid', ')', ';', '$', '.ajax', '(', '{', 'url', ':', '``', 'https', ':', '//www.analyticsvidhya.com/back-channel/check-session.php', "''", ',', 'method', ':', '``', 'POST', "''", ',', 'data', ':', '{', '``', 'session_key', "''", ':', 'payload.identityid', '}', ',', 'success', ':', 'function', '(', 'r', ')', '{', '//console.log', '(', 'r', ')', '}', '}', ')', ';', 'user_logged_in', '(', 'payload', ')', ';', '}', ',', 'error', ':', 'function', '(', ')', '{', 'console.log', '(', '``', 'error', "''", ')', '}', '}', ')', '}', '//', 'User', 'Login', 'functi ...

# %% [markdown]
# # Remove stop-words using stop-word corpus.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download the stop-words corpus 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_corpus = []
for sentence in line_tokens:
    tokenized_sentence = word_tokenize(sentence)
    filtered_sentence = [word for word in tokenized_sentence if word.lower() not in stop_words]
    filtered_corpus.append(" ".join(filtered_sentence))

print(filtered_corpus)
# Out:
# ['Natural Language Processing Corpus Linguistics Elements Corpus Linguistics Cambridge University Press Jonathan Dunn University Canterbury Abstract .', 'Corpus analysis expanded scaled incorporating computational methods natural language processing .', 'Element shows text classification text similarity models extend ability undertake corpus linguistics across large corpora .', 'computational methods coming increasingly important corpora grow large traditional types linguistic analysis .', 'draw five case studies show use computational methods , ranging usage -based grammar authorship analysis using soci al media corpus -based sociolinguistics .', 'section accompanied interactive code notebook shows implement analysis Python .', 'stand - alone Python package also available help readers use methods data .', 'large -scale analysis introduces new ethical problems , Element pairs new methodology discussion potential ethical implications .', 'Book : https : //doi.org/10.1017/9781009070447 Interactivate Notebooks : https : //doi.org/10 .24433/CO.3402613.v1 Python Package : https : //github.com/jonathandunn/text_analytics Table Contents 1 .', 'Computational Linguistic Analysis 1.1 .', 'Scaling Corpus Linguistics 1.2 .', 'Case Studies 1.3 .', 'Categorization Problems 1.4 .', 'Comparison Problems 1.5 .', 'Language Vector Space 1.6 .', 'Ethics : Data Rights 2 .', 'Text Classification 2.1 .', 'Evaluating Classifiers 2.2 .', 'Representing Content 2.3 .', 'Representing Structure 2.4 .', 'Representing Context 2.5 .', 'Representing Sentiment 2.6 .', 'Logistic Regression 2.7 .', 'Feed -Forward Networks 2.8 .', 'Ethics : Implicit Bias 3 .', 'Text Similarity 3.1 .', 'Categorization Cognition 3.2 .', 'Measuring Corpus Similarity 3.3 .', 'Measuring Document Similarity 3.4 .', 'Measuring Word Similarity Using Association 3.5 .', 'Measuring Word Similarity Vector Space 3.6 .', 'Clustering Similarit 3.7 .', 'Ethics : Model Discrimination 4 .', 'Validation Visualization 4.1 .', 'Reporting Results Political Speech Prediction 4.2 .', 'Ensuring Validity Using Box Plots 4.3 .', 'Unmasking Pseudonymous Authors Using Line Plots 4.4 .', 'Comparing Word Embeddings Using Heat Maps 4.5 .', 'Following Linguistic Diversity Using Choropleth Maps 4.6 .', 'Ethics : Equal Access 5 .', 'Conclusions 1.1 Scaling Corpus Linguistics Corpus linguistics entered golden age , driven amount range language available linguistic analysis .', "Corpus data able represent population 's usage scale , -passing limitations made introspect ion important 1950s .", 'wide availability language data requires linguists methods available analyze .', 'surge advances natural language processing computational linguistics , ad vances become increasingly disconnected corpus linguistics linguistic theory .', 'Element brings natural language processing corpus linguistics together , showing computational models used answer categorization comparison problems .', 'computational models presented using five case studies introduced next section , ranging syntactic analysis register analysis corpus -based sociolinguistics .', 'goal sh ow use computational models , linguistic questions answer , important scale corpus linguistics way .', 'linguist use Element learn use natural language processing answer linguistic qu estions already familiar .', 'computer scientist use Element learn linguistic assumptions limitations behind computational methods , matters often disregarded within natural language processing .', 'categorization problem assigning pre -defined label piece language .', 'word level , could involve asking whether particular open -class word noun verb .', 'sentence level , could asking kind cons truction particular sentence represents .', 'document level , could asking whether particular speaker represents New Zealand English Australian English .', 'questions answered using text classifier .', 'typ e supervised machine learning linguists define categories interested .', 'comparison problem measuri ...

# %% [markdown]
# # Using Spacy

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_md
# !python -m spacy download en_core_web_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-28 01:26:14.625282: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 01:26:15.745697: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:15.745845: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:15.745868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-28 01:26:17.395945: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-28 01:26:27.334627: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 01:26:28.605683: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:28.605803: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:28.605821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-28 01:26:30.219623: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-md==3.4.1) (3.4.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.22.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-28 01:26:41.433807: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 01:26:42.535913: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:42.536034: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-28 01:26:42.536058: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-28 01:26:44.157988: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-lg==3.4.1) (3.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.4.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.64.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.25.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.22.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.10.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
#Load Spacy and necessary resources
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ##  TOKENIZER

# %%
# line tokenization
lines = corpus.split("\n")

# space tokenization
spaces = [token.text for token in nlp(corpus)]

# word tokenization
words = [token.text for token in nlp(corpus) if not token.is_space]

# tweet tokenization
from spacy.lang.en import English
tweet_nlp = English()

def tweet_tokenizer(text):
    tokens = tweet_nlp(text)
    return [token.text for token in tokens if not token.is_space]

tweets = [tweet_tokenizer(line) for line in lines if line.strip()]

# %% [markdown]
# ## Lemmatization

# %%
doc = nlp(corpus)
lemmatized_text = " ".join([token.lemma_ for token in doc])
print(lemmatized_text)
# Out:
# Natural Language processing for Corpus Linguistics
#
#  Elements in Corpus   Linguistics
#
#  Cambridge University Press
#
#  Jonathan Dunn
#  University of Canterbury
#
#  Abstract . corpus analysis can be expand and scale up by incorporate computational
#  method from natural language processing . this Element show how text classification and text
#  similarity model can extend our ability to undertake corpus linguistic across very large
#  corpus . these computational method be be come increasingly important as corpora grow
#  too large for more traditional type of linguistic analysis . we draw on five case study to show
#  how and why to use computational method , range from usage -base grammar to authorship
#  analysis to use soci al media for corpus -base sociolinguistic . each section be accompany by
#  an interactive code notebook that show how to implement the analysis in Python . a stand -
#  alone Python package be also available to help reader use these method with their own datum .
#  because large -scale analysis introduce new ethical problem , this Element pair each new
#  methodology with a discussion of potential ethical implication .
#
#  Book : https://doi.org/10.1017/9781009070447
#  Interactivate Notebooks : https://doi.org/10 .24433 / co.3402613.v1
#  Python Package : https://github.com/jonathandunn/text_analytic
#
#    table of Contents
#  1 . Computational Linguistic Analysis
#  1.1 . scale up Corpus Linguistics
#  1.2 . the Case Studies
#  1.3 . Categorization problem
#  1.4 . Comparison Problems
#  1.5 . language in Vector Space
#  1.6 . ethic : Data Rights
#  2 . Text Classification
#  2.1 . evaluate Classifiers
#  2.2 . represent Content
#  2.3 . represent structure
#  2.4 . represent Context
#  2.5 . represent Sentiment
#  2.6 . Logistic Regression
#  2.7 . feed -Forward Networks
#  2.8 . ethic : Implicit Bias
#  3 . Text Similarity
#  3.1 . Categorization and Cognition
#  3.2 . measure Corpus Similarity
#  3.3 . measure Document Similarity
#  3.4 . measure Word Similarity Using Association
#  3.5 . measure Word Similarity in Vector Space
#  3.6 . cluster by Similarit y
#  3.7 . ethic : Model Discrimination
#  4 . Validation and Visualization
#  4.1 . report result for political Speech Prediction
#  4.2 . ensure validity Using Box Plots
#  4.3 . unmask pseudonymous author use Line Plots
#  4.4 . compare Word Embeddings use Heat Maps
#  4.5 . follow Linguistic Diversity use Choropleth Maps
#  4.6 . ethic : equal Access
#  5 . conclusion
#    1.1 scaling up Corpus Linguistics
#  Corpus linguistic have enter a golden age , drive by both the amount and the range of
#  language that be now available for linguistic analysis . Corpus data be able to represent a
#  population 's usage at scale , by -passe the limitation which make introspect ion so important in
#  the 1950s . but this wide availability of language datum require that linguist have the method
#  available to analyze it . and while there have be a surge of advance in natural language
#  processing and computational linguistic , these ad vance have become increasingly
#  disconnected from corpus linguistic and linguistic theory . this Element bring natural
#  language processing and corpus linguistic together , show how computational model can be
#  use to answer both categorization   and comparison   problem . these computational model
#  be present use five case study that will be introduce in the next section , range from
#  syntactic analysis to register analysis to corpus -base sociolinguistic .
#  the goal here be to sh ow how to use these computational model , what linguistic question they
#  can answer , and why it be important to scale up corpus linguistic in this way . a linguist can use
#  this Element to learn how to use natural language processing to answer linguistic qu estion
#  they be already familiar with . and a computer scientist can use this Element to learn about the
#  linguistic assumption and limitation behind computational method , matter that be too
#  often disregard within natural language processing itself .
#  a categorization problem be about assign a pre -define label to some piece of language . at
#  the word level , this could involve ask whether a particular open -class word be a noun or a
#  verb . at the sentence level , this could be ask what kind of con truction a particular sentence
#  represent . at the document level , this could be ask whether a particular speaker represent
#  New Zealand English or australian English . all of these question can be answer use a text
#  classifier . this be a typ e of supervised machine learning in which we as linguist define the
#  category that we be interested in .
#  a comparison problem be about measure the relationship between two observation . at the
#  word level , this could be ask whether two noun like cat and dog belong to the same
#  semantic domain . at the sentence level , this could ask whether two tweet have a similar
#  sentiment . at the document level , this could be ask whether two article be example of a
#  similar style . these qu estion can be approach use a text similarity model . this be a type of
#  unsupervised machine learning in which we as linguist only control the representation be
#  use , not the set of label use for annotation .
#  how well do computational mo del compare with human introspection ? in some case , model
#  can reproduce human intuition with a high degree of accuracy . for example , text classifier
#  have be show to make very good prediction about the part -of - speech of individual word
#  when traine d on small amount of annotated datum . in a case like this , a small amount of seed
#  datum , which be annotate by a linguist , support the analysis of corpora too large to be annotate
#  by a linguist . so a text classifier allow we to scale up introspection -base annotation .
#  in other case , computational model can detect pattern in language that be not visible to
#  human introspection . for example , research in both authorship analysis and dialect
#  identification have show that there be enough individual -speci fic and community -specific
#  variant to enable accurate prediction of who produce a specific document . but , as linguist ,
#  our own introspection be not precise enough to identify these same pattern . in a case like this , computational linguistic analysis   make it possible to answer new question about
#  language .
#  finally , there be case where computational model completely miss something that be easily
#  accessible to human . for example , we will follow a case -study on multi -lingualism online which
#  show t hat 90 % of digital language datum ( from the web and social medium ) represent just 20
#  language . Most language in the world be low -resource language from a computational
#  perspective . as a result , many of the computational method that we cover in this El ement be
#  difficult to apply to these language . as linguist , however , we do not require million or billion
#  of word in a language before we can begin our analysis .
#  we need computational linguistic analysis for two reason : for reproducibility   and for
#  scalability . first , every step in a computational pipeline be fully automate , which mean that it
#  can be reproduce and verify . for example , this Element follow five separate case -studie
#  that we will introduce in the next sub -section . all the graph and figure and experiment in the
#  Element can be reproduce use the code notebook that be link within each section . this be
#  an example of how computational method su pport reproducibility .
#  second , the once -revolutionary Brown Corpus contain 1 million word . but it be common now
#  for corpus to range from 1 billion word , like the GeoWAC family of corpora , up to 400 billion
#  word , like the Corpus of Global Language Use . these very large corpus be often draw from
#  digital source like the web , social medium , Wikipedia , and news article . while these source of
#  language datum have tremendous pote ntial for test linguistic hypothesis on a large scale ,
#  work with they require computational method to scale up the analysis .
#  at the same time , the combination of large digital corpora and computational linguistic analysis
#  create new ethical issue s. give that these corpus contain datum from large number of
#  individual , how do we maintain privacy ? how do we determine ownership and control over
#  both the datum and the model that be derive from the datum ? how do we prevent model from
#  perpetuate n egative stereotype that be contain in these corpus ? we will consider a range
#  of ethical question like these as we cover the core computational method .
#  this first section introduce the basic idea behind both text classification model and text
#  similarity model . but , before we look at the model themselves , we start by introduce five
#  case study that we will be follow to show how these method can be use for meaningful
#  linguistic analysis .   Assignment 1onComparative study of available library for NLPIn Subject : natural Langauge ProcessingbyPranav Bagade ( 271007)shreya Bhalgat ( 271009)Nayan Chandak ( 271013)shrirang Godbole ( 271020)department of Artificial Intelligence and Data scienceviit2022 - 2023
#  Problem StatementComparative study of available library for Natural Language processing with respect to provide functionality , platform dependence , support NLP approach , support NLP Tasks , advantage and Disadvantages etc . available library for NLPThere be many popular library for natural language processing ( NLP ) available , each with their own strength and weakness . some of the most popular library include : NLTK ( Natural Language Toolkit ): NLTK be a comprehensive library for NLP in Python , with support for many nlp task such as tokenization , stemming , and POS tagging . it also include a wide range of corpora and resource for language processing.spaCy : spaCy be another popular NLP library for Python , with a focus on efficiency and ease of use . it have a fast processing speed and be design for production use , with support for a wide range of NLP task such as name entity recognition and dependency parsing . corenlp : corenlp be a Java - base library for NLP , with support for many nlp task such as part - of - speech tagging and name entity recognition . it also include a neural network - base dependency parser , and it can be use via a web service or a command - line interface . Gensim : Gensim be a Python library for topic modeling and document similarity analysis , it be build specifically for unsupervised NLP . it also include support for word2vec and doc2vec model . opennlp : OpenNLP be an Apache - support NLP library for Java , with support for a wide range of NLP task such as tokenization , POS tagging , and name entity recognition . it be design to be easy to use and integrate into other system . Hugging Face : Hugging Face be a library that provide pre - train transformer model , it be particularly useful for NLP task such as text generation , text classification , and name entity recognition . all of these library have their own advantage and disadvantage , and the good choice of library will depend on the specific use case and requirement .
#  1 . nltknltk ( Natural Language Toolkit ) be a python library for natural language processing . it provide a variety of functionality include tokenization , stemming , and tagging , as well as wrapper for other NLP library . NLTK be platform - independent and can be use on any operating system that support Python . some of the functionality it provide include : tokenization ( splitting text into word , sentence , etc.)part - of - speech tagging ( labeling word with their grammatical role)name entity recognition ( identify people , organization , etc . in text)parse ( analyze the grammatical structure of sentences)semantic reasoning ( make inference base on the meaning of text)stemme and lemmatization ( reduce word to their base form)nltk be platform - independent , mean it can be use on any operating system that support Python . NLTK support a wide variety of NLP approach , include rule - base , statistical , and machine learning - base method . it also support a wide range of NLP task , include text classification , language modeling , and information extraction . advantage of use nltk includesIts extensive documentation and community support , as well as the wide range of NLP tool it provide . its ease of use , as it provide a simple and consistent interface for work with text datum . it also have a large community of user and developer , which mean that there be many resource available for learning and troubleshooting . DisadvantageSome of the algorithm provide by nltk be not as efficient as other library or framework . it can be slow for large amount of datum , as it be implement in pure Python . additionally , some of the algorithm and model include in NLTK may not be as advanced or accurate as those in other library or framework .
#  2 . SPACYSpaCy be a popular open - source library for natural language processing ( NLP ) in Python . some of its key functionality include tokenization , part - of - speech tagging , name entity recognition , and dependency parsing . platform dependence : SpaCy be build for Python and can be instal via pip or conda . support NLP approach : SpaCy primarily use statistical model and machine learning algorithm to perform NLP task . support NLP task : TokenizationPart - of - speech taggingname entity recognitiondependency parsinglemmatizationsentence segmentationtext classificationsimilarity comparisonadvantage : SpaCy be fast and efficient in comparison to other NLP library such as NLTK.It provide pre - train model for various language which can be easily load and use . the library be easy to use and have a clean and simple api.disadvantage : SpaCy do not provide advanced functionality such as sentiment analysis or machine translation . the library be not as widely support as NLTK and may have limit resource and tutorial available . it do not support old version of Python .
#  	 3 . GensimGensim be a Python library for topic modeling and document similarity analysis . it be platform - independent and can be use on any operating system that support Python . the library support several nlp approach , include Latent Semantic Analysis ( LSA ) , Latent Dirichlet Allocation ( LDA ) , and hierarchical Dirichlet Process ( HDP).It also support several nlp task , such as text pre - processing , text similarity calculation , and topic modeling . advantage of Gensim include its ease of use efficient processing of large dataset . support for multiple nlp approach and task . disadvantage include its limitation in handle very large dataset the need for a relatively high level of expertise to use some of its advanced feature .
#  4 . CoreNLPCoreNLP be a powerful natural language processing library develop by Stanford University . it provide a wide range of functionality for various nlp task such as tokenization , part - of - speech tagging , name entity recognition , sentiment analysis , and coreference resolution . corenlp be platform dependent , as it be write in Java and require Java 8 or high to run . it can be use on Windows , Mac , and Linux operating system . corenlp support various NLP approach , include rule - base , statistical , and neural method . it also support multiple language such as English , Arabic , Chinese , french , german , and spanish . corenlp support a wide range of NLP task , include : tokenization : break a text into individual word or phrasespart - of - Speech Tagging : identify the grammatical role of each word in a sentencename Entity Recognition : identify proper noun and other entity in a textsentiment analysis : determine the overall sentiment or emotion express in a textcoreference resolution : identify when multiple word in a text refer to the same entityadvantage of corenlp : it be a widely used and well - establish library with a large user communityit provide a wide range of functionality for various nlp tasksIt support multiple languagesIt be open - source and free to usedisadvantages of corenlp : it require a Java runtime environment , which may not be suitable for some usersIt can be challenge to install and set up , especially for user with limited programming experienceit may not be as fast or efficient as some other NLP library . Simplilearn - Online Certification Training Course Provider
#  all course
#  what do you want to learn ?
#  log in
#  AI & Machine Learning
#  Video TutorialsArticlesEbooksFree Practice testson - demand Webinars
#  HomeResourcesAI & Machine LearningArtificial Intelligence Tutorial for BeginnersWhat be NLP - an Introductory Tutorial to Natural Language Processing
#  TUTORIAL PLAYLIST
#  Artificial Intelligence Tutorial for Beginners
#  Overview
#  what be Artificial Intelligence : type , history , and Future
#  Lesson - 1
#  top 14 Artificial Intelligence Applications
#  Lesson - 2
#  how do AI work
#  Lesson - 3
#  7 type of Artificial Intelligence that you should know in 2023
#  Lesson - 4
#  discover the Differences between AI vs. Machine Learning vs. Deep Learning
#  Lesson - 5
#  what be nlp : an Introductory Tutorial to Natural Language Processing
#  Lesson - 6
#  how to become an Artificial Intelligence Engineer ?
#  Lesson - 7
#  the Top Five Humanoid Robots
#  Lesson - 8
#  all about virtual reality : what be virtual reality ?
#  Lesson - 9
#  good AR Apps in 2022
#  Lesson - 10
#  want an Easy idea about what be Augmented reality ? read this !
#  Lesson - 11
#  the Ultimate Guide to ' what be sparkar ' and its effect on Social Media
#  Lesson - 12
#  what be NLP - an Introductory Tutorial to Natural Language Processing
#  Lesson 6 of 12by Mayank Banoula
#
#  Last update on Sep 16 , 202236570
#  what be nlp : an Introductory Tutorial to Natural Language Processing
#  PreviousNext
#  Table of content
#  what be NLP?How to perform nlp?application of NLP Conclusion
#  have you ever wonder how robot such as Sophia or home assistant sound so humanlike ? how do they understand you ? all of this be because of the magic of Natural Language Processing or NLP . use nlp you can make machine sound human - like and even ' understand ' what you ’re say .
#
#  in this article on ' what be NLP ? the good introductory guide to NLP ' you will learn everything that you need to know about NLP .
#
#  what be NLP ?
#  human communicate with each other use word and text . the way that human convey information to each other be call Natural Language . every day human share a large quality of information with each other in various language as speech or text .
#
#  however , computer can not interpret this data , which be in natural language , as they communicate in 1s and 0s . the datum produce be precious and can offer valuable insight . hence , you need computer to be able to understand , emulate and respond intelligently to human speech .
#
#  Natural Language Processing or NLP refer to the branch of Artificial Intelligence that give the machine the ability to read , understand and derive meaning from human language .
#
#  PCP in AI and Machine Learning
#  in Partnership with Purdue universityexplore coursepcp in AI and Machine Learning
#  NLP combine the field of linguistic and computer science to decipher language structure and guideline and to make model which can comprehend , break down and separate significant detail from text and speech .
#
#  ConstituentsofNLP
#
#  Figure 1 : constituent of NLP
#
#  how to perform NLP ?
#  the step to perform preprocessing of datum in NLP include :
#
#  segmentation :
#  you first need to break the entire document down into its constituent sentence . you can do this by segment the article along with its punctuation like full stop and comma .
#
#     Stemming       Figure 2 : segmentation
#
#  tokenizing :
#  for the algorithm to understand these sentence , you need to get the word in a sentence and explain they individually to our algorithm . so , you break down your sentence into its constituent word and store they . this be call tokenizing , and each world be call a token .
#
#  tokenization
#
#  Figure 3 : tokenization
#
#  remove Stop word :
#  you can make the learning process fast by getting rid of non - essential word , which add little meaning to our statement and be just there to make our statement sound more cohesive . word such as be , in , be , and , the , be call stop word and can be remove .
#
#  StopWords
#
#  Figure 4 : stop word
#
#  stemming :
#  it be the process of obtain the Word Stem of a word . Word Stem give new word upon add affix to they
#
#  figure5_stemme
#
#  figure 5 : stem
#
#  lemmatization :
#  the process of obtain the Root Stem of a word . Root Stem give the new base form of a word that be present in the dictionary and from which the word be derive . you can also identify the base word for different word base on the tense , mood , gender , etc .
#
#  lemmatization
#
#  Figure 6 : lemmatization
#
#  part of Speech Tagging :
#  now , you must explain the concept of noun , verb , article , and other part of speech to the machine by add these tag to our word . this be call ' part of ' .
#
#  Figure7 .
#
#  figure 7 : part of Speech Tagging
#
#  name Entity Tagging :
#  next , introduce your machine to pop culture reference and everyday name by flag name of movie , important personality or location , etc that may occur in the document . you do this by classify the word into subcategorie . this help you find any keyword in a sentence . the subcategorie be person , location , monetary value , quantity , organization , movie .
#
#  after perform the preprocesse step , you then give your resultant datum to a machine learn algorithm like Naive Bayes , etc . , to create your NLP application .
#
#  Machine Learning Free Course
#  Start Learning today 's Most in - demand skillsexplore COURSEMachine Learning Free Course
#  Applications of NLP
#  NLP be one of the way that people have humanize machine and reduce the need for labor . it have lead to the automation of speech - relate task and human interaction . some application of NLP include :
#
#  translation Tools : tool such as Google Translate , Amazon Translate , etc . translate sentence from one language to another use NLP .
#  Chatbots : chatbot can be find on most website and be a way for company to deal with common query quickly .
#  virtual Assistants : virtual Assistants like Siri , Cortana , Google Home , Alexa , etc can not only talk to you but understand command give to they .
#  Targeted Advertising : have you ever talk about a product or service or just google something and then start see ad for it ? this be call targeted advertising , and it help generate ton of revenue for seller as they can reach niche audience at the right time .
#  Autocorrect : Autocorrect will automatically correct any spelling mistake you make , apart from this grammar checker also come into the picture which help you write flawlessly .
#  enhance your skill set and give a boost to your career with the AI and Machine Learning Courses .
#  Conclusion
#  in this article title ' what be NLP ? the good introductory guide to NLP ' , you look into the concept of NLP . follow by common NLP technique . you then see the application of NLP .
#
#  if you be look to learn the application of NLP and become an expert in Artificial Intelligence , Simplilearn 's AI Certification Training would be the ideal way to go about it . a world - class bootcamp program cover everything include NLP , Machine Learning , Deep Learning with Keras and TensorFlow , and Advanced Deep Learning topic , this be an ideal program for anyone look to make it big in the field of Artificial Intelligence and Machine Learning .
#
#  we hope this article teach you the basic of NLP and NLP datum preprocessing . do you have any doubt or question for we ? mention they in this article 's comment section , and we will have our expert answer they for you at the early !
#
#  find our Professional Certificate Program in AI and Machine Learning Online Bootcamp in top city :
#  Name 	 Date 	 Place
#  Professional Certificate Program in AI and Machine Learning 	 Cohort start on 13th Feb 2023 ,
#  Weekend batch 	 your City 	 View Details
#  Professional Certificate Program in AI and Machine Learning , Hyderabad 	 Cohort start on 27th Feb 2023 ,
#  Weekend batch 	 Hyderabad 	 View Details
#  Professional Certificate Program in AI and Machine Learning , Pune 	 Cohort start on 13th Mar 2023 ,
#  Weekend batch 	 Pune 	 View Details
#  about the Author
#  Mayank BanoulaMayank Banoula
#  Mayank be a Research Analyst at Simplilearn . he be proficient in Machine learning and artificial intelligence with python .
#  view More
#  Recommended Programs
#  Professional Certificate Program in AI and Machine Learning
#  Professional Certificate Program in AI and Machine Learning
#
#  4685 Learners
#  Lifetime Access *
#  * lifetime access to high - quality , self - pace e - learn content .
#  explore category
#  find Professional Certificate Program in AI and Machine Learning in these city
#  Professional Certificate Program in AI and Machine Learning , AhmedabadProfessional Certificate Program in AI and Machine Learning , BangaloreProfessional Certificate Program in AI and Machine Learning , ChandigarhProfessional Certificate Program in AI and Machine Learning , ChennaiProfessional Certificate Program in AI and Machine Learning , DelhiProfessional Certificate Program in AI and Machine Learning , HyderabadProfessional Certificate Program in AI and Machine Learning , KolkataProfessional Certificate Program in AI and Machine Learning , MumbaiProfessional Certificate Program in AI and Machine Learning , Pune
#  recommend Resources
#  top 10 Machine Learning Applications in 2023
#  top 10 Machine Learning Applications i …
#
#  Video Tutorial
#  the Ultimate Guide to Top Front end and back End Programming Languages for 2021
#  the Ultimate Guide to Top Front end and Bac …
#
#  Ebook
#  how to become an NLP Engineer ? Description , Skills , and Salary
#  how to become an NLP Engineer ? Description , …
#
#  article
#  what be Ethereum ? understand its Features and Applications
#  what be Ethereum ? understand its Feat …
#
#  Video Tutorial
#  A Comprehensive Look at what Business Process Management be
#  a Comprehensive Look at what Business Proc …
#
#  Video Tutorial
#  devops from Concepts to Practical Applications
#  devops from Concepts to Practical Applications
#
#  Ebook
#  prevnext
#
#  follow we !
#
#  refer and Earn
#  Company
#
#  about we
#  career
#  in the medium
#  Alumni speak
#  Grievance redressal
#  contact we
#  work with we
#
#  Become an instructor
#  blog as guest
#  Discover
#
#  Skillup
#  Skillup Sitemap
#  Resources
#  RSS feed
#  Simplilearn Coupons and Discount Offers
#  City Sitemap
#  for business
#
#  corporate training
#  Partners
#  Digital Transformation
#  Learn on the go !
#
#  get the Android App
#  get the ios App
#  Trending Post Graduate Programs
#
#  Project Management Certification Course | Cyber Security Certification Course | Lean six Sigma Certification Course | Advanced Certificate Program in Data Science | Data Analytics Program | AI and ML Course | Business Analysis Certification Course | Data Engineering Certification Courses | Digital Marketing Certification Program | Cloud Computing Certification Course | Full Stack web Development Course | Digital Marketing Bootcamp
#  Trending Master Programs
#
#  PMP plus Certification Training Course | Data Science Certifiation Course | Data Analyst Course | Artificial Intelligence Course | Cloud Architect Certification Training Course | DevOps Engineer Certification Training Course | Digital Marketing Course | Cyber Security Expert Course | MEAN Stack Developer course
#  trend course
#
#  PMP Certification Training Course | CSM Certification Course | Data Science with Python Course | Tableau Certification Course | Power BI Certification Course | TOGAF Certification Course | ITIL 4 Foundation Certification Training Course | AWS Solutions Architect Certification Training Course | CISSP Certification training | Java Certification Course | Python Certification Training Course | Big Data Hadoop course
#  Trending Resources
#
#  Python Tutorial | JavaScript Tutorial | Java Tutorial | Angular Tutorial | Node.js Tutorial | Docker Tutorial | Git Tutorial | Kubernetes Tutorial | Power BI Tutorial | CSS Tutorial
#  term of UsePrivacy PolicyRefund PolicyReschedule Policy
#  Address : NALANDA 53/1 C , Manoj Arcade , 24th Main Rd , Sector 2 , HSR Layout , Bengaluru - 560102 , Karnataka , India . Phone no:1800 - 212 - 7688
#  © 2009 - 2023 - Simplilearn Solutions . all Rights Reserved . the certification name be the trademark of their respective owner .
#  Disclaimer
#  PMP , PMI , PMBOK , CAPM , PgMP , PfMP , ACP , PBA , RMP , SP , and OPM3 be register mark of the Project Management Institute , Inc.
#  * accord to simplilearn survey conduct and subject to term & condition with Ernst & Young LLP ( EY ) as Process Advisors
#
#  level - up your experience for free !
#  Course RecommendationsSalary GuidesPersonalized NewslettersSurprise Rewards
#
#
#
#  natural language processing - Wikipedia
#  document.documentelement.classname="client - js vector - feature - language - in - header - enable vector - feature - language - in - main - page - header - disabled vector - feature - language - alert - in - sidebar - enable vector - feature - sticky - header - disabled vector - feature - page - tool - disabled vector - feature - page - tool - pin - disabled vector - feature - main - menu - pin - disabled vector - feature - limit - width - enable vector - feature - limit - width - content - enabled";(function(){var cookie = document.cookie.match(/(?:^| ; ) enwikimwclientprefs=([^;]+)/);if(cookie){var featureName = cookie[1];document.documentelement.classname = document.documentelement.classname.replace(featurename+'-enabled',featurename+'-disabled');}}());rlconf={"wgbreakframes":false,"wgseparatortransformtable":["",""],"wgdigittransformtable":["",""],"wgdefaultdateformat":"dmy","wgmonthnames":["","january","february","march","april","may","june","july","august","september","october","november","december"],"wgrequestid":"408d91d8 - f237 - 4dd3 - b51b-2ec1ba6df7b0 " ,
#  " wgcspnonce":false,"wgcanonicalnamespace":"","wgcanonicalspecialpagename":false,"wgnamespacenumber":0,"wgpagename":"natural_language_processing","wgtitle":"natural language processing","wgcurrevisionid":1141420081,"wgrevisionid":1141420081,"wgarticleid":21652,"wgisarticle":true,"wgisredirect":false,"wgaction":"view","wgusername":null,"wgusergroups":["*"],"wgcategories":["all accuracy disputes","Accuracy dispute from December 2013","cs1 maint : location","article with short description","short description be different from wikidata","common category link from wikidata","article with J9U identifiers","Articles with LCCN identifiers","article with NDL identifiers","article with NKC identifiers","natural language processing","computational field of study","computational linguistics","speech recognition"],"wgpagecontentlanguage":"en","wgpagecontentmodel":"wikitext","wgrelevantpagename":"natural_language_processing","wgrelevantarticleid":21652,"wgisprobablyeditable":true ,
#  " wgrelevantpageisprobablyeditable":true,"wgrestrictionedit":[],"wgrestrictionmove":[],"wgflaggedrevsparams":{"tags":{"status":{"levels":1}}},"wgvisualeditor":{"pagelanguagecode":"en","pagelanguagedir":"ltr","pagevariantfallbacks":"en"},"wgmfdisplaywikibasedescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgwmeschemaeditattemptstepoversample":false,"wgwmepagelength":50000,"wgnoticeproject":"wikipedia","wgvector2022previewpages":[],"wgmediavieweronclick":true,"wgmediaviewerenabledbydefault":true,"wgpopupsflags":10,"wgulscurrentautonym":"english","wgeditsubmitbuttonlabelpublish":true,"wgcentralauthmobiledomain":false,"wgulsposition":"interlanguage","wgulsiscompactlinksenabled":true,"wgulsislanguageselectorempty":false,"wgwikibaseitemid":"q30642","gehomepagesuggestededitsenabletopics":true,"wggetopicsmatchmodeenabled":false,"wggestructuredtaskrejectionreasontextinputenabled":false};rlstate={"skins.vector.user.styles":"ready","ext.globalcssjs.user.styles":"ready "
#  , " site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalcssjs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.makecollapsible.styles":"ready","ext.visualeditor.desktoparticletarget.noscript":"ready","ext.wikimediabadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};rlpagemodules=["ext.cite.ux - enhancements","ext.math.scripts","site","mediawiki.page.ready","jquery.makecollapsible","mediawiki.toc","skins.vector.js","skins.vector.es6","mmv.head","mmv.bootstrap.autostart","ext.visualeditor.desktoparticletarget.init","ext.visualeditor.targetloader","ext.eventlogging","ext.wikimediaevents","ext.navigationtiming","ext.cx.eventlogging.campaigns","ext.centralnotice.geoip","ext.centralnotice.startup","ext.gadget . ReferenceTooltips","ext.gadget.charinsert " ,
#  " ext.gadget.extra - toolbar - buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.growthexperiment . suggestededitsession " ] ;
#  ( RLQ = window . rlq||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jquery , require , module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\ " } ) ; } ) ; } ) ;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  jump to content
#
#
#
#
#
#  Toggle sidebar
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create accountLog in
#
#
#
#
#
#  personal tool
#
#
#
#
#   create account Log in
#
#
#
#
# 		 page for log out editor learn more
#
#
#  ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Navigation
#
#
#  main pagecontentscurrent eventsrandom articleabout WikipediaContact usDonate
#
#
#
#
#  contribute
#
#
#  HelpLearn to editcommunity portalrecent changesupload file
#
#
#
#
#  Tools
#
#
#  what link hererelate changesupload filespecial pagespermanent linkpage informationCite this pageWikidata item
#
#
#
#
#  Print / export
#
#
#  download as pdfprintable version
#
#
#
#
#  in other project
#
#
#  Wikimedia CommonsWikiversity
#
#
#
#
#  Languages
#
#  on this Wikipedia the language link be at the top of the page across from the article title . go to top .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  content
#  move to sidebar
#  hide
#
#
#
#
#  ( Top )
#
#
#
#
#
#  1history
#
#
# 				 Toggle History subsection
#
#
#
#
#
#  1.1symbolic NLP ( 1950 – early 1990 )
#
#
#
#
#
#
#
#  1.2statistical NLP ( 1990s–2010s )
#
#
#
#
#
#
#
#  1.3Neural NLP ( present )
#
#
#
#
#
#
#
#
#
#  2method : rule , statistic , neural network
#
#
# 				 Toggle Methods : rule , statistic , neural network subsection
#
#
#
#
#
#  2.1statistical method
#
#
#
#
#
#
#
#  2.2Neural network
#
#
#
#
#
#
#
#
#
#  3common NLP task
#
#
# 				 Toggle Common NLP task subsection
#
#
#
#
#
#  3.1text and speech processing
#
#
#
#
#
#
#
#  3.2morphological analysis
#
#
#
#
#
#
#
#  3.3syntactic analysis
#
#
#
#
#
#
#
#  3.4lexical semantic ( of individual word in context )
#
#
#
#
#
#
#
#  3.5relational semantic ( semantic of individual sentence )
#
#
#
#
#
#
#
#  3.6discourse ( semantic beyond individual sentence )
#
#
#
#
#
#
#
#  3.7higher - level NLP application
#
#
#
#
#
#
#
#
#
#  4general tendency and ( possible ) future direction
#
#
# 				 Toggle General tendency and ( possible ) future direction subsection
#
#
#
#
#
#  4.1cognition and NLP
#
#
#
#
#
#
#
#
#
#  5see also
#
#
#
#
#
#
#
#  6reference
#
#
#
#
#
#
#
#  7Further read
#
#
#
#
#
#
#
#  8external link
#
#
#
#
#
#
#
#
#
#
#
#
# 						 Toggle the table of content
#
#
#
#
#  Toggle the table of content
#
#
#
#
#
#
#  natural language processing
#
#
#
#  59 language
#
#
#
#  AfrikaansالعربيةAzərbaycancaবাংলাBân - lâm - gúБеларускаяБеларуская ( тарашкевіца)БългарскиBosanskiCatalàČeštinaDanskDeutschEestiΕλληνικάEspañolEsperantoEuskaraفارسیFrançaisGalego한국어Հայերենहिन्दीHrvatskiBahasa IndonesiaIsiZuluÍslenskaItalianoעבריתಕನ್ನಡქართულიLietuviųМакедонскиमराठीمصرىМонголမြန်မာဘာသာ日本語ଓଡ଼ିଆPicardPiemontèisPolskiPortuguêsRomânăRuna SimiРусскийSimple EnglishکوردیСрпски / srpskiSrpskohrvatski / српскохрватскиSuomiதமிழ்ไทยTürkçeУкраїнськаTiếng Việt粵語中文
#  Edit link
#
#
#
#
#
#
#
#
#
#
#  ArticleTalk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#  readeditview history
#
#
#
#
#
#
#
#  More
#
#
#
#  readeditview history
#
#
#
#
#
#
#
#
#
#
#
#  from Wikipedia , the free encyclopedia
#
#
#  Field of linguistic and computer science
#  .mw - parser - output .hatnote{font - style : italic}.mw - parser - output div.hatnote{padde - left:1.6em;margin - bottom:0.5em}.mw - parser - output .hatnote i{font - style : normal}.mw - parser - output .hatnote+link+.hatnote{margin - top:-0.5em}this article be about natural language processing do by computer . for the natural language processing do by the human brain , see language processing in the brain .
#   an automate online assistant provide customer service on a web page , an example of an application where natural language processing be a major component[1 ]
#  natural language processing ( NLP ) be an interdisciplinary subfield of linguistic , computer science , and artificial intelligence concern with the interaction between computer and human language , in particular how to program computer to process and analyze large amount of natural language datum .   the goal be a computer capable of " understand " the content of document , include the contextual nuance of the language within they . the technology can then accurately extract information and insight contain in the document as well as categorize and organize the document themselves .
#  challenge in natural language processing frequently involve speech recognition , natural - language understanding , and natural - language generation .
#
#
#  history[edit ]
#  further information : history of natural language processing
#  natural language processing have its root in the 1950 . already in 1950 , Alan Turing publish an article title " Computing Machinery and Intelligence " which propose what be now call the turing test as a criterion of intelligence , though at the time that be not articulate as a problem separate from artificial intelligence . the propose test include a task that involve the automate interpretation and generation of natural language .
#
#  symbolic NLP ( 1950 – early 1990s)[edit ]
#  the premise of symbolic nlp be well - summarize by John Searle 's chinese room experiment : give a collection of rule ( e.g. , a chinese phrasebook , with question and matching answer ) , the computer emulate natural language understanding ( or other nlp task ) by apply those rule to the datum it confront .
#
#  1950 : the Georgetown experiment in 1954 involve fully automatic translation of more than sixty russian sentence into English . the author claim that within three or five year , machine translation would be a solved problem.[2 ]   however , real progress be much slow , and after the ALPAC report in 1966 , which find that ten - year - long research have fail to fulfill the expectation , funding for machine translation be dramatically reduce .   little further research in machine translation be conduct in America ( though some research continue elsewhere , such as Japan and europe[3 ] ) until the late 1980 when the first statistical machine translation system be develop .
#  1960 : some notably successful natural language processing system develop in the 1960 be SHRDLU , a natural language system work in restricted " block world " with restricted vocabulary , and ELIZA , a simulation of a rogerian psychotherapist , write by Joseph Weizenbaum between 1964 and 1966 .   use almost no information about human thought or emotion , ELIZA sometimes provide a startlingly human - like interaction . when the " patient " exceed the very small knowledge base , ELIZA might provide a generic response , for example , respond to " my head hurt " with " why do you say your head hurt ? " .
#  1970 : during the 1970s , many programmer begin to write " conceptual ontology " , which structure real - world information into computer - understandable datum .   example be MARGIE ( Schank , 1975 ) , SAM ( Cullingford , 1978 ) , PAM ( Wilensky , 1978 ) , TaleSpin ( Meehan , 1976 ) , QUALM ( Lehnert , 1977 ) , Politics ( Carbonell , 1979 ) , and Plot Units ( Lehnert 1981 ) .   during this time , the first chatterbot be write ( e.g. , PARRY ) .
#  1980 : the 1980 and early 1990 mark the heyday of symbolic method in NLP . focus area of the time include research on rule - base parsing ( e.g. , the development of HPSG as a computational operationalization of generative grammar ) , morphology ( e.g. , two - level morphology[4 ] ) , semantic ( e.g. , Lesk algorithm ) , reference ( e.g. , within center Theory[5 ] ) and other area of natural language understanding ( e.g. , in the Rhetorical Structure theory ) . other line of research be continue , e.g. , the development of chatterbot with Racter and Jabberwacky . an important development ( that eventually lead to the statistical turn in the 1990s ) be the rise importance of quantitative evaluation in this period.[6 ]
#  statistical nlp ( 1990s–2010s)[edit ]
#  up to the 1980s , most natural language processing system be base on complex set of hand - write rule .   start in the late 1980 , however , there be a revolution in natural language processing with the introduction of machine learning algorithm for language processing .   this be due to both the steady increase in computational power ( see Moore 's law ) and the gradual lessening of the dominance of chomskyan theory of linguistic ( e.g. transformational grammar ) , whose theoretical underpinning discourage the sort of corpus linguistic that underlie the machine - learn approach to language processing.[7 ]
#
#  1990 : many of the notable early success on statistical method in NLP occur in the field of machine translation , due especially to work at IBM Research , such as IBM alignment model .   these system be able to take advantage of exist multilingual textual corpus that have be produce by the Parliament of Canada and the European Union as a result of law call for the translation of all governmental proceeding into all official language of the correspond system of government .   however , most other system depend on corpus specifically develop for the task implement by these system , which be ( and often continue to be ) a major limitation in the success of these system . as a result , a great deal of research have go into method of more effectively learn from limited amount of datum .
#  2000 : with the growth of the web , increase amount of raw ( unannotated ) language datum have become available since the mid-1990 . research have thus increasingly focus on unsupervised and semi - supervised learning algorithm .   such algorithm can learn from datum that have not be hand - annotate with the desire answer or use a combination of annotated and non - annotated datum .   generally , this task be much more difficult than supervised learning , and typically produce less accurate result for a give amount of input datum .   however , there be an enormous amount of non - annotated datum available ( include , among other thing , the entire content of the World Wide Web ) , which can often make up for the inferior result if the algorithm use have a low enough time complexity to be practical .
#  Neural nlp ( present)[edit ]
#  in the 2010s , representation learning and deep neural network - style machine learning method become widespread in natural language processing . that popularity be due partly to a flurry of result show that such techniques[8][9 ] can achieve state - of - the - art result in many natural language task , e.g. , in language modeling[10 ] and parsing.[11][12 ] this be increasingly important in medicine and healthcare , where NLP helps analyze note and text in electronic health record that would otherwise be inaccessible for study when seek to improve care.[13 ]
#
#  Methods : rule , statistic , neural networks[edit ]
#  in the early day , many language - processing system be design by symbolic method , i.e. , the hand - coding of a set of rule , couple with a dictionary lookup:[14][15 ] such as by write grammar or devise heuristic rule for stem .
#  more recent system base on machine - learning algorithm have many advantage over hand - produce rule :
#
#  the learning procedure use during machine learning automatically focus on the most common case , whereas when write rule by hand it be often not at all obvious where the effort should be direct .
#  automatic learning procedure can make use of statistical inference algorithm to produce model that be robust to unfamiliar input ( e.g. contain word or structure that have not be see before ) and to erroneous input ( e.g. with misspelled word or word accidentally omit ) . generally , handle such input gracefully with handwritten rule , or , more generally , create system of handwritten rule that make soft decision , be extremely difficult , error - prone and time - consume .
#  Systems base on automatically learn the rule can be make more accurate simply by supply more input datum . however , system base on handwritten rule can only be make more accurate by increase the complexity of the rule , which be a much more difficult task . in particular , there be a limit to the complexity of system base on handwritten rule , beyond which the system become more and more unmanageable . however , create more datum to input to machine - learn system simply require a corresponding increase in the number of man - hour work , generally without significant increase in the complexity of the annotation process .
#  despite the popularity of machine learning in NLP research , symbolic method be still ( 2020 ) commonly use :
#
#  when the amount of training data be insufficient to successfully apply machine learning method , e.g. , for the machine translation of low - resource language such as provide by the Apertium system ,
#  for preprocesse in NLP pipeline , e.g. , tokenization , or
#  for postprocesse and transform the output of NLP pipeline , e.g. , for knowledge extraction from syntactic parse .
#  statistical methods[edit ]
#  since the so - call " statistical revolution"[16][17 ] in the late 1980 and mid-1990 , much natural language processing research have rely heavily on machine learning . the machine - learn paradigm call instead for use statistical inference to automatically learn such rule through the analysis of large corpora ( the plural form of corpus , be a set of document , possibly with human or computer annotation ) of typical real - world example .
#  many different class of machine - learning algorithm have be apply to natural - language - processing task . these algorithm take as input a large set of " feature " that be generate from the input datum . increasingly , however , research have focus on statistical model , which make soft , probabilistic decision base on attach real - value weight to each input feature ( complex - value embeddings,[18 ] and neural network in general have also be propose , for e.g. speech[19 ] ) . such model have the advantage that they can express the relative certainty of many different possible answer rather than only one , produce more reliable result when such a model be include as a component of a large system .
# ...
#
#  ^ Strauss , Claudia ( 1999 ) . a cognitive theory of Cultural Meaning . Cambridge University Press . pp .   156–164 . ISBN   978 - 0 - 521 - 59541 - 4 .
#
#  ^ " Universal Conceptual Cognitive Annotation ( UCCA ) " . Universal Conceptual Cognitive Annotation ( UCCA ) . retrieve 2021 - 01 - 11 .
#
#  ^ Rodríguez , F. C. , & Mairal - Usón , R. ( 2016 ) . build an RRG computational grammar . Onomazein , ( 34 ) , 86 - 117 .
#
#  ^ " Fluid Construction Grammar – a fully operational processing system for construction grammar " . retrieve 2021 - 01 - 11 .
#
#  ^ " ACL Member Portal | the Association for Computational Linguistics Member Portal " . www.aclweb.org . retrieve 2021 - 01 - 11 .
#
#  ^ " Chunks and rule " . www.w3.org . retrieve 2021 - 01 - 11 .
#
#  ^ Socher , Richard ; Karpathy , Andrej ; Le , Quoc V. ; Manning , Christopher D. ; Ng , Andrew Y. ( 2014 ) . " Grounded Compositional Semantics for finding and Describing Images with sentence " . transaction of the Association for Computational Linguistics . 2 : 207–218 . doi:10.1162 / tacl_a_00177 . S2CID   2317858 .
#
#
#  further reading[edit ]
#  .mw - parser - output .refbegin{font - size:90%;margin - bottom:0.5em}.mw - parser - output .refbegin - hang - indent > ul{margin - left:0}.mw - parser - output .refbegin - hang - indent > ul > li{margin - left:0;padde - left:3.2em;text - indent:-3.2em}.mw - parser - output .refbegin - hang - indent ul,.mw - parser - output .refbegin - hang - indent ul li{list - style : none}@media(max - width:720px){.mw - parser - output .refbegin - hang - indent > ul > li{padde - left:1.6em;text - indent:-1.6em}}.mw - parser - output .refbegin - columns{margin - top:0.3em}.mw - parser - output .refbegin - column ul{margin - top:0}.mw - parser - output .refbegin - column li{page - break - inside : avoid;break - inside : avoid - column }
#  Bates , M ( 1995 ) . " model of natural language understanding " . proceeding of the National Academy of Sciences of the United States of America . 92 ( 22 ): 9977–9982 . bibcode:1995pnas ... 92.9977b. doi:10.1073 / pnas.92.22.9977 . PMC   40721 . PMID   7479812 .
#  Steven Bird , Ewan Klein , and Edward Loper ( 2009 ) . Natural Language Processing with Python . O'Reilly Media . ISBN   978 - 0 - 596 - 51649 - 9 .
#  Daniel Jurafsky and James H. Martin ( 2008 ) . Speech and Language Processing , 2nd edition . Pearson Prentice Hall . isbn   978 - 0 - 13 - 187321 - 6 .
#  Mohamed Zakaria Kurdi ( 2016 ) . Natural Language Processing and Computational Linguistics : speech , morphology , and syntax , volume 1 . ISTE - Wiley . ISBN   978 - 1848218482 .
#  Mohamed Zakaria Kurdi ( 2017 ) . Natural Language Processing and Computational Linguistics : semantic , discourse , and application , volume 2 . ISTE - Wiley . ISBN   978 - 1848219212 .
#  Christopher D. Manning , Prabhakar Raghavan , and Hinrich Schütze ( 2008 ) . introduction to Information Retrieval . Cambridge University Press . ISBN   978 - 0 - 521 - 86571 - 5 . official html and pdf version available without charge .
#  Christopher D. Manning and Hinrich Schütze ( 1999 ) . foundation of Statistical Natural Language Processing . the MIT Press . ISBN   978 - 0 - 262 - 13360 - 9 .
#  David M. W. Powers and Christopher C. R. Turk ( 1989 ) . Machine Learning of Natural Language . Springer - Verlag . ISBN   978 - 0 - 387 - 19557 - 5 .
#
#  external links[edit ]
#   medium relate to natural language processing at Wikimedia Commons
#  .mw - parser - output .hlist dl,.mw - parser - output .hlist ol,.mw - parser - output .hlist ul{margin:0;padding:0}.mw - parser - output .hlist dd,.mw - parser - output .hlist dt,.mw - parser - output .hlist li{margin:0;display : inline}.mw - parser - output .hlist.inline,.mw - parser - output .hlist.inline dl,.mw - parser - output .hlist.inline ol,.mw - parser - output .hlist.inline ul,.mw - parser - output .hlist dl dl,.mw - parser - output .hlist dl ol,.mw - parser - output .hlist dl ul,.mw - parser - output .hlist ol dl,.mw - parser - output .hlist ol ol,.mw - parser - output .hlist ol ul,.mw - parser - output .hlist ul dl,.mw - parser - output .hlist ul ol,.mw - parser - output .hlist ul ul{display : inline}.mw - parser - output .hlist .mw - empty - li{display : none}.mw - parser - output .hlist dt::after{content : " : " } .mw - parser - output .hlist dd::after,.mw - parser - output .hlist li::after{content : " · " ; font - weight : bold}.mw - parser - output .hlist dd : last - child::after,.mw - parser - output .hlist dt : last - child::after,.mw - parser - output .hlist li : last - child::after{content : none}.mw - parser - output .hlist dd dd : first - child::before,.mw - parser - output .hlist dd dt : first - child::before,.mw - parser - output .hlist dd li : first - child::before,.mw - parser - output .hlist dt dd : first - child::before,.mw - parser - output .hlist dt dt : first - child::before,.mw - parser - output .hlist dt li : first - child::before,.mw - parser - output .hlist li dd : first - child::before,.mw - parser - output .hlist li dt : first - child::before,.mw - parser - output .hlist li li : first - child::before{content : " ( " ; font - weight : normal}.mw - parser - output .hlist dd dd : last - child::after,.mw - parser - output .hlist dd dt : last - child::after,.mw - parser - output .hlist dd li : last - child::after,.mw - parser - output .hlist dt dd : last - child::after,.mw - parser - output .hlist dt dt : last - child::after,.mw - parser - output .hlist dt li : last - child::after,.mw - parser - output .hlist li dd : last - child::after,.mw - parser - output .hlist li dt : last - child::after,.mw - parser - output .hlist li li : last - child::after{content:")";font - weight : normal}.mw - parser - output .hlist ol{counter - reset : listitem}.mw - parser - output .hlist ol > li{counter - increment : listitem}.mw - parser - output .hlist ol > li::before{content : " " counter(listitem)"\a0 " } .mw - parser - output .hlist dd ol > li : first - child::before,.mw - parser - output .hlist dt ol > li : first - child::before,.mw - parser - output .hlist li ol > li : first - child::before{content : " ( " counter(listitem)"\a0 " } .mw - parser - output .navbox{box - sizing : border - box;border:1px solid # a2a9b1;width:100%;clear : both;font - size:88%;text - align : center;padding:1px;margin:1em auto 0}.mw - parser - output .navbox .navbox{margin - top:0}.mw - parser - output .navbox+.navbox,.mw - parser - output .navbox+.navbox - styles+.navbox{margin - top:-1px}.mw - parser - output .navbox - inner,.mw - parser - output .navbox - subgroup{width:100%}.mw - parser - output .navbox - group,.mw - parser - output .navbox - title,.mw - parser - output .navbox - abovebelow{padding:0.25em 1em;line - height:1.5em;text - align : center}.mw - parser - output .navbox - group{white - space : nowrap;text - align : right}.mw - parser - output .navbox,.mw - parser - output .navbox - subgroup{background - color:#fdfdfd}.mw - parser - output .navbox - list{line - height:1.5em;border - color:#fdfdfd}.mw - parser - output .navbox - list - with - group{text - align : left;border - leave - width:2px;border - leave - style : solid}.mw - parser - output tr+tr>.navbox - abovebelow,.mw - parser - output tr+tr>.navbox - group,.mw - parser - output tr+tr>.navbox - image,.mw - parser - output tr+tr>.navbox - list{border - top:2px solid # fdfdfd}.mw - parser - output .navbox - title{background - color:#ccf}.mw - parser - output .na ...
#  AI - complete
#  Bag - of - word
#  n - gram
#  Bigram
#  Trigram
#  Computational linguistic
#  natural - language understanding
#  stop word
#  text processing
#  Text analysis
#  collocation extraction
#  Concept mining
#  Coreference resolution
#  deep linguistic processing
#  distant reading
#  information extraction
#  name - entity recognition
#  ontology learn
#  Parsing
#  part - of - speech tag
#  semantic role label
#  semantic similarity
#  Sentiment analysis
#  terminology extraction
#  Text mining
#  textual entailment
#  Truecasing
#  word - sense disambiguation
#  word - sense induction
#  Text segmentation
#  compound - term processing
#  Lemmatisation
#  Lexical analysis
#  Text chunk
#  Stemming
#  Sentence segmentation
#  Word segmentation
#
#  automatic summarization
#  multi - document summarization
#  Sentence extraction
#  Text simplification
#  machine translation
#  Computer - assist
#  Example - base
#  Rule - base
#  statistical
#  transfer - base
#  Neural
#  Distributional semantic model
#  BERT
#  Document - term matrix
#  explicit semantic analysis
#  fasttext
#  GloVe
#  Language model
#  latent semantic analysis
#  seq2seq
#  Word embed
#  Word2vec
#  Language resource , dataset and corporatype andstandard
#  Corpus linguistic
#  lexical resource
#  Linguistic Linked Open Data
#  machine - readable dictionary
#  parallel text
#  PropBank
#  semantic network
#  Simple Knowledge Organization System
#  Speech corpus
#  Text corpus
#  Thesaurus ( information retrieval )
#  Treebank
#  Universal Dependencies
#  Data
#  BabelNet
#  Bank of English
#  DBpedia
#  FrameNet
#  Google Ngram Viewer
#  UBY
#  WordNet
#  automatic identificationand datum capture
#  Speech recognition
#  Speech segmentation
#  Speech synthesis
#  natural language generation
#  optical character recognition
#  topic model
#  Document classification
#  Latent Dirichlet allocation
#  Pachinko allocation
#  computer - assistedreviewe
#  Automated essay scoring
#  Concordancer
#  Grammar checker
#  predictive text
#  Speech verification
#  Spell checker
#  Syntax guess
#  natural languageuser interface
#  Chatbot
#  interactive fiction
#  question answer
#  virtual assistant
#  Voice user interface
#  relate
#  Hallucination
#  Natural Language toolkit
#  spaCy
#
#  .mw - parser - output .portal - bar{font - size:88%;font - weight : bold;display : flex;justify - content : center;align - item : baseline}.mw - parser - output .portal - bar - bordered{padding:0 2em;background - color:#fdfdfd;border:1px solid # a2a9b1;clear : both;margin:1em auto 0}.mw - parser - output .portal - bar - related{font - size:100%;justify - content : flex - start}.mw - parser - output .portal - bar - unbordered{padding:0 1.7em;margin - left:0}.mw - parser - output .portal - bar - header{margin:0 1em 0 0.5em;flex:0 0 auto;min - height:24px}.mw - parser - output .portal - bar - content{display : flex;flex - flow : row wrap;flex:0 1 auto;padding:0.15em 0;column - gap:1em;align - item : baseline;margin:0;list - style : none}.mw - parser - output .portal - bar - content - related{margin:0;list - style : none}.mw - parser - output .portal - bar - item{display : inline - block;margin:0.15em 0.2em;min - height:24px;line - height:24px}@media screen and ( max - width:768px){.mw - parser - output .portal - bar{font - size:88%;font - weight : bold;display : flex;flex - flow : column wrap;align - item : baseline}.mw - parser - output .portal - bar - header{text - align : center;flex:0;padde - left:0.5em;margin:0 auto}.mw - parser - output .portal - bar - related{font - size:100%;align - item : flex - start}.mw - parser - output .portal - bar - content{display : flex;flex - flow : row wrap;align - item : center;flex:0;column - gap:1em;border - top:1px solid # a2a9b1;margin:0 auto;list - style : none}.mw - parser - output .portal - bar - content - related{border - top : none;margin:0;list - style : none}}.mw - parser - output .navbox+link+.portal - bar,.mw - parser - output .navbox+style+.portal - bar,.mw - parser - output .navbox+link+.portal - bar - bordered,.mw - parser - output .navbox+style+.portal - bar - bordered,.mw - parser - output .sister - bar+link+.portal - bar,.mw - parser - output .sister - bar+style+.portal - bar,.mw - parser - output .portal - bar+.navbox - styles+.navbox,.mw - parser - output .portal - bar+.navbox - styles+.sister - bar{margin - top:-1px}portal :   language
#  .mw - parser - output .tooltip - dotted{border - bottom:1px dotted;cursor : help}authority control : National librarie
#  Israel
#  United States
#  Japan
#  Czech Republic
#
#
#
#
#
#  retrieve from " https://en.wikipedia.org/w/index.php?title=natural_language_processing&oldid=1141420081 "
#  Categories : natural language processingcomputational field of studycomputational linguisticsspeech recognitionhidden category : all accuracy disputesaccuracy dispute from December 2013CS1 maint : locationarticle with short descriptionshort description be different from WikidataCommons category link from WikidataArticles with J9U identifiersarticle with LCCN identifiersarticle with NDL identifiersarticle with NKC identifier
#
#
#
#
#
#
#   this page be last edit on 25 February 2023 , at 00:09   ( UTC ) .
#  Text be available under the Creative Commons Attribution - ShareAlike License 3.0 ;
#  additional term may apply .   by use this site , you agree to the term of Use and Privacy Policy . Wikipedia ® be a registered trademark of the Wikimedia Foundation , Inc. , a non - profit organization .
#
#
#  Privacy policy
#  about Wikipedia
#  Disclaimers
#  Contact Wikipedia
#  Mobile view
#  Developers
#  Statistics
#  Cookie statement
#
#
#
#
#
#
#
#
#
#  ( RLQ = window . RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.887","walltime":"1.120","ppvisitednodes":{"value":4945,"limit":1000000},"postexpandincludesize":{"value":126265,"limit":2097152},"templateargumentsize":{"value":3171,"limit":2097152},"expansiondepth":{"value":14,"limit":100},"expensivefunctioncount":{"value":9,"limit":500},"unstrip - depth":{"value":1,"limit":20},"unstrip - size":{"value":163974,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00 %   955.865       1 -total " , " 47.61 %   455.079       1 template : reflist " , " 11.53 %   110.239      22 Template : Cite_web " , " 10.34 %    98.820       1 template : natural_language_processing " , " 10.25 %    97.956       3 Template : Navbox " , "   9.65 %    92.255       1 template : cite_conference " , "   8.98 %    85.792      12 Template : cite_journal " , "   7.34 %    70.202       1 template : Commonscatinline " , "   7.04 %    67.274       1 template : sister - inline " , "   6.37 %    60.854       1 template : Short_description"]},"scribunto":{"limitreport - timeusage":{"value":"0.540","limit":"10.000"},"limitreport - memusage":{"value":6852625,"limit":52428800}},"cachereport":{"origin":"mw1477","timestamp":"20230226192653","ttl":1814400,"transientcontent":false } } } ) ; } ) ;
#  { " @context":"https:\/\/schema.org","@type":"article","name":"natural language processing","url":"https:\/\/en.wikipedia.org\/wiki\/natural_language_processing","sameas":"http:\/\/www.wikidata.org\/entity\/q30642","mainentity":"http:\/\/www.wikidata.org\/entity\/q30642","author":{"@type":"organization","name":"contributor to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation , Inc. ","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf - hor - googpub.png"}},"datepublished":"2001 - 09 - 22t05:47:41z","datemodified":"2023 - 02 - 25t00:09:38z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/8b\/automated_online_assistant.png","headline":"field of computer science and linguistics"}{"@context":"https:\/\/schema.org","@type":"Article","name":"Natural language processing","url":"https:\/\/en.wikipedia.org\/wiki\/natural_language_processing","sameas":"http:\/\/www.wikidata.org\/entity\/q30642","mainentity":"http:\/\/www.wikidata.org\/entity\/q30642","author":{"@type":"organization","name":"contributor to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation , Inc. ","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf - hor - googpub.png"}},"datepublished":"2001 - 09 - 22t05:47:41z","datemodified":"2023 - 02 - 25t00:09:38z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/8b\/automated_online_assistant.png","headline":"field of computer science and linguistic " }
#  ( RLQ = window . rlq||[]).push(function(){mw.config.set({"wgbackendresponsetime":137,"wghostname":"mw1441 " } ) ; } ) ;

# %% [markdown]
# ## Stemming using porter stemmer

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

stemmed_text = " ".join([stemmer.stem(token.text) for token in doc])
print(stemmed_text)
# Out:
# natur languag process for corpu linguist
#
#  element in corpu   linguist
#
#  cambridg univers press
#
#  jonathan dunn
#  univers of canterburi
#
#  abstract . corpu analysi can be expand and scale up by incorpor comput
#  method from natur languag process . thi element show how text classif and text
#  similar model can extend our abil to undertak corpu linguist across veri larg
#  corpora . these comput method are be come increasingli import as corpora grow
#  too larg for more tradit type of linguist analysi . we draw on five case studi to show
#  how and whi to use comput method , rang from usag -base grammar to authorship
#  analysi to use soci al media for corpu -base sociolinguist . each section is accompani by
#  an interact code notebook that show how to implement the analysi in python . a stand -
#  alon python packag is also avail to help reader use these method with their own data .
#  becaus larg -scale analysi introduc new ethic problem , thi element pair each new
#  methodolog with a discuss of potenti ethic implic .
#
#  book : https://doi.org/10.1017/9781009070447
#  interactiv notebook : https://doi.org/10 .24433 / co.3402613.v1
#  python packag : https://github.com/jonathandunn/text_analyt
#
#    tabl of content
#  1 . comput linguist analysi
#  1.1 . scale up corpu linguist
#  1.2 . the case studi
#  1.3 . categor problem
#  1.4 . comparison problem
#  1.5 . languag in vector space
#  1.6 . ethic : data right
#  2 . text classif
#  2.1 . evalu classifi
#  2.2 . repres content
#  2.3 . repres structur
#  2.4 . repres context
#  2.5 . repres sentiment
#  2.6 . logist regress
#  2.7 . feed -forward network
#  2.8 . ethic : implicit bia
#  3 . text similar
#  3.1 . categor and cognit
#  3.2 . measur corpu similar
#  3.3 . measur document similar
#  3.4 . measur word similar use associ
#  3.5 . measur word similar in vector space
#  3.6 . cluster by similarit y
#  3.7 . ethic : model discrimin
#  4 . valid and visual
#  4.1 . report result for polit speech predict
#  4.2 . ensur valid use box plot
#  4.3 . unmask pseudonym author use line plot
#  4.4 . compar word embed use heat map
#  4.5 . follow linguist divers use choropleth map
#  4.6 . ethic : equal access
#  5 . conclus
#    1.1 scale up corpu linguist
#  corpu linguist ha enter a golden age , driven by both the amount and the rang of
#  languag that is now avail for linguist analysi . corpu data is abl to repres a
#  popul 's usag at scale , by -pass the limit which made introspect ion so import in
#  the 1950 . but thi wide avail of languag data requir that linguist have the method
#  avail to analyz it . and while there ha been a surg of advanc in natur languag
#  process and comput linguist , these ad vanc have becom increasingli
#  disconnect from corpu linguist and linguist theori . thi element bring natur
#  languag process and corpu linguist togeth , show how comput model can be
#  use to answer both categor   and comparison   problem . these comput model
#  are present use five case studi that will be introduc in the next section , rang from
#  syntact analysi to regist analysi to corpu -base sociolinguist .
#  the goal here is to sh ow how to use these comput model , what linguist question they
#  can answer , and whi it is import to scale up corpu linguist in thi way . a linguist can use
#  thi element to learn how to use natur languag process to answer linguist qu estion
#  they are alreadi familiar with . and a comput scientist can use thi element to learn about the
#  linguist assumpt and limit behind comput method , matter that are too
#  often disregard within natur languag process itself .
#  a categor problem is about assign a pre -defin label to some piec of languag . at
#  the word level , thi could involv ask whether a particular open -class word is a noun or a
#  verb . at the sentenc level , thi could be ask what kind of con truction a particular sentenc
#  repres . at the document level , thi could be ask whether a particular speaker repres
#  new zealand english or australian english . all of these question can be answer use a text
#  classifi . thi is a typ e of supervis machin learn in which we as linguist defin the
#  categori that we are interest in .
#  a comparison problem is about measur the relationship between two observ . at the
#  word level , thi could be ask whether two noun like cat and dog belong to the same
#  semant domain . at the sentenc level , thi could ask whether two tweet have a similar
#  sentiment . at the document level , thi could be ask whether two articl are exampl of a
#  similar style . these qu estion can be approach use a text similar model . thi is a type of
#  unsupervis machin learn in which we as linguist onli control the represent be
#  use , not the set of label use for annot .
#  how well do comput mo del compar with human introspect ? in some case , model
#  can reproduc human intuit with a high degre of accuraci . for exampl , text classifi
#  have been shown to make veri good predict about the part -of - speech of individu word
#  when train d on small amount of annot data . in a case like thi , a small amount of seed
#  data , which is annot by a linguist , support the analysi of corpora too larg to be annot
#  by a linguist . so a text classifi allow us to scale up introspect -base annot .
#  in other case , comput model can detect pattern in languag that are not visibl to
#  human introspect . for exampl , research in both authorship analysi and dialect
#  identif ha shown that there are enough individu -speci fic and commun -specif
#  variant to enabl accur predict of who produc a specif document . but , as linguist ,
#  our own introspect are not precis enough to identifi these same pattern . in a case like thi , comput linguist analysi   make it possibl to answer new question about
#  languag .
#  final , there are case where comput model complet miss someth that is easili
#  access to human . for exampl , we will follow a case -studi on multi -lingual onlin which
#  show t hat 90 % of digit languag data ( from the web and social media ) repres just 20
#  languag . most languag in the world are low -resourc languag from a comput
#  perspect . as a result , mani of the comput method that we cover in thi el ement are
#  difficult to appli to these languag . as linguist , howev , we do not requir million or billion
#  of word in a languag befor we can begin our analysi .
#  we need comput linguist analysi for two reason : for reproduc   and for
#  scalabl . first , everi step in a comput pipelin is fulli autom , which mean that it
#  can be reproduc and verifi . for exampl , thi element follow five separ case -studi
#  that we will introduc in the next sub -section . all the graph and figur and experi in the
#  element can be reproduc use the code notebook that are link within each section . thi is
#  an exampl of how comput method su pport reproduc .
#  second , the onc -revolutionari brown corpu contain 1 million word . but it is common now
#  for corpora to rang from 1 billion word , like the geowac famili of corpora , up to 400 billion
#  word , like the corpu of global languag use . these veri larg corpora are often drawn from
#  digit sourc like the web , social media , wikipedia , and news articl . while these sourc of
#  languag data have tremend pote ntial for test linguist hypothes on a larg scale ,
#  work with them requir comput method to scale up the analysi .
#  at the same time , the combin of larg digit corpora and comput linguist analysi
#  creat new ethic issu s. given that these corpora contain data from larg number of
#  individu , how do we maintain privaci ? how do we determin ownership and control over
#  both the data and the model that are deriv from the data ? how do we prevent model from
#  perpetu n eg stereotyp that are contain in these corpora ? we will consid a rang
#  of ethic question like these as we cover the core comput method .
#  thi first section introduc the basic idea behind both text classif model and text
#  similar model . but , befor we look at the model themselv , we start by introduc five
#  case studi that we will be follow to show how these method can be use for meaning
#  linguist analysi .   assign 1oncompar studi of avail librari for nlpin subject : natur langaug processingbypranav bagad ( 271007)shreya bhalgat ( 271009)nayan chandak ( 271013)shrirang godbol ( 271020)depart of artifici intellig and data scienceviit2022 - 2023
#  problem statementcompar studi of avail librari for natur languag process with respect to provid function , platform depend , support nlp approach , support nlp task , advantag and disadvantag etc . avail librari for nlpthere are mani popular librari for natur languag process ( nlp ) avail , each with their own strength and weak . some of the most popular librari includ : nltk ( natur languag toolkit ): nltk is a comprehens librari for nlp in python , with support for mani nlp task such as token , stem , and po tag . it also includ a wide rang of corpora and resourc for languag processing.spaci : spaci is anoth popular nlp librari for python , with a focu on effici and eas of use . it ha a fast process speed and is design for product use , with support for a wide rang of nlp task such as name entiti recognit and depend pars . corenlp : corenlp is a java - base librari for nlp , with support for mani nlp task such as part - of - speech tag and name entiti recognit . it also includ a neural network - base depend parser , and it can be use via a web servic or a command - line interfac . gensim : gensim is a python librari for topic model and document similar analysi , it 's built specif for unsupervis nlp . it also includ support for word2vec and doc2vec model . opennlp : opennlp is an apach - support nlp librari for java , with support for a wide rang of nlp task such as token , po tag , and name entiti recognit . it is design to be easi to use and integr into other system . hug face : hug face is a librari that provid pre - train transform model , it 's particularli use for nlp task such as text gener , text classif , and name entiti recognit . all of these librari have their own advantag and disadvantag , and the best choic of librari will depend on the specif use case and requir .
#  1 . nltknltk ( natur languag toolkit ) is a python librari for natur languag process . it provid a varieti of function includ token , stem , and tag , as well as wrapper for other nlp librari . nltk is platform - independ and can be use on ani oper system that support python . some of the function it provid includ : token ( split text into word , sentenc , etc.)part - of - speech tag ( label word with their grammat role)nam entiti recognit ( identifi peopl , organ , etc . in text)pars ( analyz the grammat structur of sentences)semant reason ( make infer base on the mean of text)stem and lemmat ( reduc word to their base form)nltk is platform - independ , mean it can be use on ani oper system that support python . nltk support a wide varieti of nlp approach , includ rule - base , statist , and machin learn - base method . it also support a wide rang of nlp task , includ text classif , languag model , and inform extract . advantag of use nltk includesit extens document and commun support , as well as the wide rang of nlp tool it provid . it eas of use , as it provid a simpl and consist interfac for work with text data . it also ha a larg commun of user and develop , which mean that there are mani resourc avail for learn and troubleshoot . disadvantagesom of the algorithm provid by nltk are not as effici as other librari or framework . it can be slow for larg amount of data , as it is implement in pure python . addit , some of the algorithm and model includ in nltk may not be as advanc or accur as those in other librari or framework .
#  2 . spacyspaci is a popular open - sourc librari for natur languag process ( nlp ) in python . some of it key function includ token , part - of - speech tag , name entiti recognit , and depend pars . platform depend : spaci is built for python and can be instal via pip or conda . support nlp approach : spaci primarili use statist model and machin learn algorithm to perform nlp task . support nlp task : tokenizationpart - of - speech taggingnam entiti recognitiondepend parsinglemmatizationsent segmentationtext classificationsimilar comparisonadvantag : spaci is fast and effici in comparison to other nlp librari such as nltk.it provid pre - train model for variou languag which can be easili load and use . the librari is easi to use and ha a clean and simpl api.disadvantag : spaci doe not provid advanc function such as sentiment analysi or machin translat . the librari is not as wide support as nltk and may have limit resourc and tutori avail . it doe not support older version of python .
#  	 3 . gensimgensim is a python librari for topic model and document similar analysi . it is platform - independ and can be use on ani oper system that support python . the librari support sever nlp approach , includ latent semant analysi ( lsa ) , latent dirichlet alloc ( lda ) , and hierarch dirichlet process ( hdp).it also support sever nlp task , such as text pre - process , text similar calcul , and topic model . advantag of gensim includ it eas of use effici process of larg dataset . support for multipl nlp approach and task . disadvantag includ it limit in handl veri larg dataset the need for a rel high level of expertis to use some of it advanc featur .
#  4 . corenlpcorenlp is a power natur languag process librari develop by stanford univers . it provid a wide rang of function for variou nlp task such as token , part - of - speech tag , name entiti recognit , sentiment analysi , and corefer resolut . corenlp is platform depend , as it is written in java and requir java 8 or higher to run . it can be use on window , mac , and linux oper system . corenlp support variou nlp approach , includ rule - base , statist , and neural method . it also support multipl languag such as english , arab , chines , french , german , and spanish . corenlp support a wide rang of nlp task , includ : token : break a text into individu word or phrasespart - of - speech tag : identifi the grammat role of each word in a sentencenam entiti recognit : identifi proper noun and other entiti in a textsenti analysi : determin the overal sentiment or emot express in a textcorefer resolut : identifi when multipl word in a text refer to the same entityadvantag of corenlp : it is a wide use and well - establish librari with a larg user communityit provid a wide rang of function for variou nlp tasksit support multipl languagesit is open - sourc and free to usedisadvantag of corenlp : it requir a java runtim environ , which may not be suitabl for some usersit can be challeng to instal and set up , especi for user with limit program experienceit may not be as fast or effici as some other nlp librari . simplilearn - onlin certif train cours provid
#  all cours
#  what do you want to learn ?
#  log in
#  ai & machin learn
#  video tutorialsarticlesebooksfre practic testson - demand webinar
#  homeresourcesai & machin learningartifici intellig tutori for beginnerswhat is nlp - an introductori tutori to natur languag process
#  tutori playlist
#  artifici intellig tutori for beginn
#  overview
#  what is artifici intellig : type , histori , and futur
#  lesson - 1
#  top 14 artifici intellig applic
#  lesson - 2
#  how doe ai work
#  lesson - 3
#  7 type of artifici intellig that you should know in 2023
#  lesson - 4
#  discov the differ between ai vs. machin learn vs. deep learn
#  lesson - 5
#  what is nlp : an introductori tutori to natur languag process
#  lesson - 6
#  how to becom an artifici intellig engin ?
#  lesson - 7
#  the top five humanoid robot
#  lesson - 8
#  all about virtual realiti : what is virtual realiti ?
#  lesson - 9
#  best ar app in 2022
#  lesson - 10
#  want an easi idea about what is augment realiti ? read thi !
#  lesson - 11
#  the ultim guid to ‘ what is sparkar ’ and it effect on social media
#  lesson - 12
#  what is nlp - an introductori tutori to natur languag process
#  lesson 6 of 12bi mayank banoula
#
#  last updat on sep 16 , 202236570
#  what is nlp : an introductori tutori to natur languag process
#  previousnext
#  tabl of content
#  what is nlp?how to perform nlp?applic of nlp conclus
#  have you ever wonder how robot such as sophia or home assist sound so humanlik ? how do they understand you ? all of thi is becaus of the magic of natur languag process or nlp . use nlp you can make machin sound human - like and even ‘ understand ’ what you ’re say .
#
#  in thi articl on ‘ what is nlp ? the best introductori guid to nlp ’ you will learn everyth that you need to know about nlp .
#
#  what is nlp ?
#  human commun with each other use word and text . the way that human convey inform to each other is call natur languag . everi day human share a larg qualiti of inform with each other in variou languag as speech or text .
#
#  howev , comput can not interpret thi data , which is in natur languag , as they commun in 1s and 0s . the data produc is preciou and can offer valuabl insight . henc , you need comput to be abl to understand , emul and respond intellig to human speech .
#
#  natur languag process or nlp refer to the branch of artifici intellig that give the machin the abil to read , understand and deriv mean from human languag .
#
#  pcp in ai and machin learn
#  in partnership with purdu universityexplor coursepcp in ai and machin learn
#  nlp combin the field of linguist and comput scienc to deciph languag structur and guidelin and to make model which can comprehend , break down and separ signific detail from text and speech .
#
#  constituentsofnlp
#
#  figur 1 : constitu of nlp
#
#  how to perform nlp ?
#  the step to perform preprocess of data in nlp includ :
#
#  segment :
#  you first need to break the entir document down into it constitu sentenc . you can do thi by segment the articl along with it punctuat like full stop and comma .
#
#     stem       figur 2 : segment
#
#  token :
#  for the algorithm to understand these sentenc , you need to get the word in a sentenc and explain them individu to our algorithm . so , you break down your sentenc into it constitu word and store them . thi is call token , and each world is call a token .
#
#  token
#
#  figur 3 : token
#
#  remov stop word :
#  you can make the learn process faster by get rid of non - essenti word , which add littl mean to our statement and are just there to make our statement sound more cohes . word such as wa , in , is , and , the , are call stop word and can be remov .
#
#  stopword
#
#  figur 4 : stop word
#
#  stem :
#  it is the process of obtain the word stem of a word . word stem give new word upon ad affix to them
#
#  figure5_stem
#
#  figur 5 : stem
#
#  lemmat :
#  the process of obtain the root stem of a word . root stem give the new base form of a word that is present in the dictionari and from which the word is deriv . you can also identifi the base word for differ word base on the tens , mood , gender , etc .
#
#  lemmat
#
#  figur 6 : lemmat
#
#  part of speech tag :
#  now , you must explain the concept of noun , verb , articl , and other part of speech to the machin by ad these tag to our word . thi is call ‘ part of ’ .
#
#  figure7 .
#
#  figur 7 : part of speech tag
#
#  name entiti tag :
#  next , introduc your machin to pop cultur refer and everyday name by flag name of movi , import person or locat , etc that may occur in the document . you do thi by classifi the word into subcategori . thi help you find ani keyword in a sentenc . the subcategori are person , locat , monetari valu , quantiti , organ , movi .
#
#  after perform the preprocess step , you then give your result data to a machin learn algorithm like naiv bay , etc . , to creat your nlp applic .
#
#  machin learn free cours
#  start learn today 's most in - demand skillsexplor coursemachin learn free cours
#  applic of nlp
#  nlp is one of the way that peopl have human machin and reduc the need for labor . it ha led to the autom of speech - relat task and human interact . some applic of nlp includ :
#
#  translat tool : tool such as googl translat , amazon translat , etc . translat sentenc from one languag to anoth use nlp .
#  chatbot : chatbot can be found on most websit and are a way for compani to deal with common queri quickli .
#  virtual assist : virtual assist like siri , cortana , googl home , alexa , etc can not onli talk to you but understand command given to them .
#  target advertis : have you ever talk about a product or servic or just googl someth and then start see ad for it ? thi is call target advertis , and it help gener ton of revenu for seller as they can reach nich audienc at the right time .
#  autocorrect : autocorrect will automat correct ani spell mistak you make , apart from thi grammar checker also come into the pictur which help you write flawlessli .
#  enhanc your skill set and give a boost to your career with the ai and machin learn cours .
#  conclus
#  in thi articl titl ‘ what is nlp ? the best introductori guid to nlp ’ , you look into the concept of nlp . follow by common nlp techniqu . you then saw the applic of nlp .
#
#  if you are look to learn the applic of nlp and becom an expert in artifici intellig , simplilearn 's ai certif train would be the ideal way to go about it . a world - class bootcamp program cover everyth includ nlp , machin learn , deep learn with kera and tensorflow , and advanc deep learn topic , thi is an ideal program for anyon look to make it big in the field of artifici intellig and machin learn .
#
#  we hope thi articl taught you the basic of nlp and nlp data preprocess . do you have ani doubt or question for us ? mention them in thi articl 's comment section , and we 'll have our expert answer them for you at the earliest !
#
#  find our profession certif program in ai and machin learn onlin bootcamp in top citi :
#  name 	 date 	 place
#  profession certif program in ai and machin learn 	 cohort start on 13th feb 2023 ,
#  weekend batch 	 your citi 	 view detail
#  profession certif program in ai and machin learn , hyderabad 	 cohort start on 27th feb 2023 ,
#  weekend batch 	 hyderabad 	 view detail
#  profession certif program in ai and machin learn , pune 	 cohort start on 13th mar 2023 ,
#  weekend batch 	 pune 	 view detail
#  about the author
#  mayank banoulamayank banoula
#  mayank is a research analyst at simplilearn . he is profici in machin learn and artifici intellig with python .
#  view more
#  recommend program
#  profession certif program in ai and machin learn
#  profession certif program in ai and machin learn
#
#  4685 learner
#  lifetim access *
#  * lifetim access to high - qualiti , self - pace e - learn content .
#  explor categori
#  find profession certif program in ai and machin learn in these citi
#  profession certif program in ai and machin learn , ahmedabadprofession certif program in ai and machin learn , bangaloreprofession certif program in ai and machin learn , chandigarhprofession certif program in ai and machin learn , chennaiprofession certif program in ai and machin learn , delhiprofession certif program in ai and machin learn , hyderabadprofession certif program in ai and machin learn , kolkataprofession certif program in ai and machin learn , mumbaiprofession certif program in ai and machin learn , pune
#  recommend resourc
#  top 10 machin learn applic in 2023
#  top 10 machin learn applic i …
#
#  video tutori
#  the ultim guid to top front end and back end program languag for 2021
#  the ultim guid to top front end and bac …
#
#  ebook
#  how to becom an nlp engin ? descript , skill , and salari
#  how to becom an nlp engin ? descript , …
#
#  articl
#  what is ethereum ? understand it featur and applic
#  what is ethereum ? understand it feat …
#
#  video tutori
#  a comprehens look at what busi process manag is
#  a comprehens look at what busi proc …
#
#  video tutori
#  devop from concept to practic applic
#  devop from concept to practic applic
#
#  ebook
#  prevnext
#
#  follow us !
#
#  refer and earn
#  compani
#
#  about us
#  career
#  in the media
#  alumni speak
#  grievanc redress
#  contact us
#  work with us
#
#  becom an instructor
#  blog as guest
#  discov
#
#  skillup
#  skillup sitemap
#  resourc
#  rss feed
#  simplilearn coupon and discount offer
#  citi sitemap
#  for busi
#
#  corpor train
#  partner
#  digit transform
#  learn on the go !
#
#  get the android app
#  get the io app
#  trend post graduat program
#
#  project manag certif cours | cyber secur certif cours | lean six sigma certif cours | advanc certif program in data scienc | data analyt program | ai and ml cours | busi analysi certif cours | data engin certif cours | digit market certif program | cloud comput certif cours | full stack web develop cours | digit market bootcamp
#  trend master program
#
#  pmp plu certif train cours | data scienc certifi cours | data analyst cours | artifici intellig cours | cloud architect certif train cours | devop engin certif train cours | digit market cours | cyber secur expert cours | mean stack develop cours
#  trend cours
#
#  pmp certif train cours | csm certif cours | data scienc with python cours | tableau certif cours | power bi certif cours | togaf certif cours | itil 4 foundat certif train cours | aw solut architect certif train cours | cissp certif train | java certif cours | python certif train cours | big data hadoop cours
#  trend resourc
#
#  python tutori | javascript tutori | java tutori | angular tutori | node.j tutori | docker tutori | git tutori | kubernet tutori | power bi tutori | css tutori
#  term of useprivaci policyrefund policyreschedul polici
#  address : nalanda 53/1 c , manoj arcad , 24th main rd , sector 2 , hsr layout , bengaluru - 560102 , karnataka , india . phone no:1800 - 212 - 7688
#  © 2009 - 2023 - simplilearn solut . all right reserv . the certif name are the trademark of their respect owner .
#  disclaim
#  pmp , pmi , pmbok , capm , pgmp , pfmp , acp , pba , rmp , sp , and opm3 are regist mark of the project manag institut , inc.
#  * accord to simplilearn survey conduct and subject to term & condit with ernst & young llp ( ey ) as process advisor
#
#  level - up your experi for free !
#  cours recommendationssalari guidesperson newsletterssurpris reward
#
#
#
#  natur languag process - wikipedia
#  document.documentelement.classname="cli - js vector - featur - languag - in - header - enabl vector - featur - languag - in - main - page - header - disabl vector - featur - languag - alert - in - sidebar - enabl vector - featur - sticki - header - disabl vector - featur - page - tool - disabl vector - featur - page - tool - pin - disabl vector - featur - main - menu - pin - disabl vector - featur - limit - width - enabl vector - featur - limit - width - content - enabled";(function(){var cooki = document.cookie.match(/(?:^| ; ) enwikimwclientprefs=([^;]+)/);if(cookie){var featurenam = cookie[1];document.documentelement.classnam = document.documentelement.classname.replace(featurename+'-enabled',featurename+'-disabled');}}());rlconf={"wgbreakframes":false,"wgseparatortransformtable":["",""],"wgdigittransformtable":["",""],"wgdefaultdateformat":"dmy","wgmonthnames":["","january","february","march","april","may","june","july","august","september","october","november","december"],"wgrequestid":"408d91d8 - f237 - 4dd3 - b51b-2ec1ba6df7b0 " ,
#  " wgcspnonce":false,"wgcanonicalnamespace":"","wgcanonicalspecialpagename":false,"wgnamespacenumber":0,"wgpagename":"natural_language_processing","wgtitle":"natur languag processing","wgcurrevisionid":1141420081,"wgrevisionid":1141420081,"wgarticleid":21652,"wgisarticle":true,"wgisredirect":false,"wgaction":"view","wgusername":null,"wgusergroups":["*"],"wgcategories":["al accuraci disputes","accuraci disput from decemb 2013","cs1 maint : location","articl with short description","short descript is differ from wikidata","common categori link from wikidata","articl with j9u identifiers","articl with lccn identifiers","articl with ndl identifiers","articl with nkc identifiers","natur languag processing","comput field of study","comput linguistics","speech recognition"],"wgpagecontentlanguage":"en","wgpagecontentmodel":"wikitext","wgrelevantpagename":"natural_language_processing","wgrelevantarticleid":21652,"wgisprobablyeditable":tru ,
#  " wgrelevantpageisprobablyeditable":true,"wgrestrictionedit":[],"wgrestrictionmove":[],"wgflaggedrevsparams":{"tags":{"status":{"levels":1}}},"wgvisualeditor":{"pagelanguagecode":"en","pagelanguagedir":"ltr","pagevariantfallbacks":"en"},"wgmfdisplaywikibasedescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgwmeschemaeditattemptstepoversample":false,"wgwmepagelength":50000,"wgnoticeproject":"wikipedia","wgvector2022previewpages":[],"wgmediavieweronclick":true,"wgmediaviewerenabledbydefault":true,"wgpopupsflags":10,"wgulscurrentautonym":"english","wgeditsubmitbuttonlabelpublish":true,"wgcentralauthmobiledomain":false,"wgulsposition":"interlanguage","wgulsiscompactlinksenabled":true,"wgulsislanguageselectorempty":false,"wgwikibaseitemid":"q30642","gehomepagesuggestededitsenabletopics":true,"wggetopicsmatchmodeenabled":false,"wggestructuredtaskrejectionreasontextinputenabled":false};rlstate={"skins.vector.user.styles":"ready","ext.globalcssjs.user.styles":"readi "
#  , " site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalcssjs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.makecollapsible.styles":"ready","ext.visualeditor.desktoparticletarget.noscript":"ready","ext.wikimediabadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};rlpagemodules=["ext.cite.ux - enhancements","ext.math.scripts","site","mediawiki.page.ready","jquery.makecollapsible","mediawiki.toc","skins.vector.js","skins.vector.es6","mmv.head","mmv.bootstrap.autostart","ext.visualeditor.desktoparticletarget.init","ext.visualeditor.targetloader","ext.eventlogging","ext.wikimediaevents","ext.navigationtiming","ext.cx.eventlogging.campaigns","ext.centralnotice.geoip","ext.centralnotice.startup","ext.gadget . referencetooltips","ext.gadget.charinsert " ,
#  " ext.gadget.extra - toolbar - buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.growthexperi . suggestededitsess " ] ;
#  ( rlq = window . rlq||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jqueri , requir , module){mw.user.tokens.set({"patroltoken":"+\\","watchtoken":"+\\","csrftoken":"+\\ " } ) ; } ) ; } ) ;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  jump to content
#
#
#
#
#
#  toggl sidebar
#
#
#
#
#
#
#
#
#
#
#
#
#  search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  creat accountlog in
#
#
#
#
#
#  person tool
#
#
#
#
#   creat account log in
#
#
#
#
# 		 page for log out editor learn more
#
#
#  contributionstalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#  navig
#
#
#  main pagecontentscurr eventsrandom articleabout wikipediacontact usdon
#
#
#
#
#  contribut
#
#
#  helplearn to editcommun portalrec changesupload file
#
#
#
#
#  tool
#
#
#  what link hererel changesupload filespeci pagesperman linkpag informationcit thi pagewikidata item
#
#
#
#
#  print / export
#
#
#  download as pdfprintabl version
#
#
#
#
#  in other project
#
#
#  wikimedia commonswikivers
#
#
#
#
#  languag
#
#  on thi wikipedia the languag link are at the top of the page across from the articl titl . go to top .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  content
#  move to sidebar
#  hide
#
#
#
#
#  ( top )
#
#
#
#
#
#  1histori
#
#
# 				 toggl histori subsect
#
#
#
#
#
#  1.1symbol nlp ( 1950 – earli 1990 )
#
#
#
#
#
#
#
#  1.2statist nlp ( 1990s–2010 )
#
#
#
#
#
#
#
#  1.3neural nlp ( present )
#
#
#
#
#
#
#
#
#
#  2method : rule , statist , neural network
#
#
# 				 toggl method : rule , statist , neural network subsect
#
#
#
#
#
#  2.1statist method
#
#
#
#
#
#
#
#  2.2neural network
#
#
#
#
#
#
#
#
#
#  3common nlp task
#
#
# 				 toggl common nlp task subsect
#
#
#
#
#
#  3.1text and speech process
#
#
#
#
#
#
#
#  3.2morpholog analysi
#
#
#
#
#
#
#
#  3.3syntact analysi
#
#
#
#
#
#
#
#  3.4lexic semant ( of individu word in context )
#
#
#
#
#
#
#
#  3.5relat semant ( semant of individu sentenc )
#
#
#
#
#
#
#
#  3.6discours ( semant beyond individu sentenc )
#
#
#
#
#
#
#
#  3.7higher - level nlp applic
#
#
#
#
#
#
#
#
#
#  4gener tendenc and ( possibl ) futur direct
#
#
# 				 toggl gener tendenc and ( possibl ) futur direct subsect
#
#
#
#
#
#  4.1cognit and nlp
#
#
#
#
#
#
#
#
#
#  5see also
#
#
#
#
#
#
#
#  6refer
#
#
#
#
#
#
#
#  7further read
#
#
#
#
#
#
#
#  8extern link
#
#
#
#
#
#
#
#
#
#
#
#
# 						 toggl the tabl of content
#
#
#
#
#  toggl the tabl of content
#
#
#
#
#
#
#  natur languag process
#
#
#
#  59 languag
#
#
#
#  afrikaansالعربيةazərbaycancaবাংলাbân - lâm - gúбеларускаябеларуская ( тарашкевіца)българскиbosanskicatalàčeštinadanskdeutscheestiελληνικάespañolesperantoeuskaraفارسیfrançaisgalego한국어հայերենहिन्दीhrvatskibahasa indonesiaisizuluíslenskaitalianoעבריתಕನ್ನಡქართულიlietuviųмакедонскиमराठीمصرىмонголမြန်မာဘာသာ日本語ଓଡ଼ିଆpicardpiemontèispolskiportuguêsromânăruna simiрусскийsimpl englishکوردیсрпски / srpskisrpskohrvatski / српскохрватскиsuomiதமிழ்ไทยtürkçeукраїнськаtiếng việt粵語中文
#  edit link
#
#
#
#
#
#
#
#
#
#
#  articletalk
#
#
#
#
#
#  english
#
#
#
#
#
#
#
#
#
#
#
#
#
#  readeditview histori
#
#
#
#
#
#
#
#  more
#
#
#
#  readeditview histori
#
#
#
#
#
#
#
#
#
#
#
#  from wikipedia , the free encyclopedia
#
#
#  field of linguist and comput scienc
#  .mw - parser - output .hatnote{font - style : italic}.mw - parser - output div.hatnote{pad - left:1.6em;margin - bottom:0.5em}.mw - parser - output .hatnot i{font - style : normal}.mw - parser - output .hatnote+link+.hatnote{margin - top:-0.5em}thi articl is about natur languag process done by comput . for the natur languag process done by the human brain , see languag process in the brain .
#   an autom onlin assist provid custom servic on a web page , an exampl of an applic where natur languag process is a major component[1 ]
#  natur languag process ( nlp ) is an interdisciplinari subfield of linguist , comput scienc , and artifici intellig concern with the interact between comput and human languag , in particular how to program comput to process and analyz larg amount of natur languag data .   the goal is a comput capabl of " understand " the content of document , includ the contextu nuanc of the languag within them . the technolog can then accur extract inform and insight contain in the document as well as categor and organ the document themselv .
#  challeng in natur languag process frequent involv speech recognit , natur - languag understand , and natur - languag gener .
#
#
#  history[edit ]
#  further inform : histori of natur languag process
#  natur languag process ha it root in the 1950 . alreadi in 1950 , alan ture publish an articl titl " comput machineri and intellig " which propos what is now call the ture test as a criterion of intellig , though at the time that wa not articul as a problem separ from artifici intellig . the propos test includ a task that involv the autom interpret and gener of natur languag .
#
#  symbol nlp ( 1950 – earli 1990s)[edit ]
#  the premis of symbol nlp is well - summar by john searl 's chines room experi : given a collect of rule ( e.g. , a chines phrasebook , with question and match answer ) , the comput emul natur languag understand ( or other nlp task ) by appli those rule to the data it confront .
#
#  1950 : the georgetown experi in 1954 involv fulli automat translat of more than sixti russian sentenc into english . the author claim that within three or five year , machin translat would be a solv problem.[2 ]   howev , real progress wa much slower , and after the alpac report in 1966 , which found that ten - year - long research had fail to fulfil the expect , fund for machin translat wa dramat reduc .   littl further research in machin translat wa conduct in america ( though some research continu elsewher , such as japan and europe[3 ] ) until the late 1980 when the first statist machin translat system were develop .
#  1960 : some notabl success natur languag process system develop in the 1960 were shrdlu , a natur languag system work in restrict " block world " with restrict vocabulari , and eliza , a simul of a rogerian psychotherapist , written by joseph weizenbaum between 1964 and 1966 .   use almost no inform about human thought or emot , eliza sometim provid a startlingli human - like interact . when the " patient " exceed the veri small knowledg base , eliza might provid a gener respons , for exampl , respond to " my head hurt " with " whi do you say your head hurt ? " .
#  1970 : dure the 1970 , mani programm began to write " conceptu ontolog " , which structur real - world inform into comput - understand data .   exampl are margi ( schank , 1975 ) , sam ( cullingford , 1978 ) , pam ( wilenski , 1978 ) , talespin ( meehan , 1976 ) , qualm ( lehnert , 1977 ) , polit ( carbonel , 1979 ) , and plot unit ( lehnert 1981 ) .   dure thi time , the first chatterbot were written ( e.g. , parri ) .
#  1980 : the 1980 and earli 1990 mark the heyday of symbol method in nlp . focu area of the time includ research on rule - base pars ( e.g. , the develop of hpsg as a comput operation of gener grammar ) , morpholog ( e.g. , two - level morphology[4 ] ) , semant ( e.g. , lesk algorithm ) , refer ( e.g. , within center theory[5 ] ) and other area of natur languag understand ( e.g. , in the rhetor structur theori ) . other line of research were continu , e.g. , the develop of chatterbot with racter and jabberwacki . an import develop ( that eventu led to the statist turn in the 1990 ) wa the rise import of quantit evalu in thi period.[6 ]
#  statist nlp ( 1990s–2010s)[edit ]
#  up to the 1980 , most natur languag process system were base on complex set of hand - written rule .   start in the late 1980 , howev , there wa a revolut in natur languag process with the introduct of machin learn algorithm for languag process .   thi wa due to both the steadi increas in comput power ( see moor 's law ) and the gradual lessen of the domin of chomskyan theori of linguist ( e.g. transform grammar ) , whose theoret underpin discourag the sort of corpu linguist that underli the machin - learn approach to languag processing.[7 ]
#
#  1990 : mani of the notabl earli success on statist method in nlp occur in the field of machin translat , due especi to work at ibm research , such as ibm align model .   these system were abl to take advantag of exist multilingu textual corpora that had been produc by the parliament of canada and the european union as a result of law call for the translat of all government proceed into all offici languag of the correspond system of govern .   howev , most other system depend on corpora specif develop for the task implement by these system , which wa ( and often continu to be ) a major limit in the success of these system . as a result , a great deal of research ha gone into method of more effect learn from limit amount of data .
#  2000 : with the growth of the web , increas amount of raw ( unannot ) languag data ha becom avail sinc the mid-1990 . research ha thu increasingli focus on unsupervis and semi - supervis learn algorithm .   such algorithm can learn from data that ha not been hand - annot with the desir answer or use a combin of annot and non - annot data .   gener , thi task is much more difficult than supervis learn , and typic produc less accur result for a given amount of input data .   howev , there is an enorm amount of non - annot data avail ( includ , among other thing , the entir content of the world wide web ) , which can often make up for the inferior result if the algorithm use ha a low enough time complex to be practic .
#  neural nlp ( present)[edit ]
#  in the 2010 , represent learn and deep neural network - style machin learn method becam widespread in natur languag process . that popular wa due partli to a flurri of result show that such techniques[8][9 ] can achiev state - of - the - art result in mani natur languag task , e.g. , in languag modeling[10 ] and parsing.[11][12 ] thi is increasingli import in medicin and healthcar , where nlp help analyz note and text in electron health record that would otherwis be inaccess for studi when seek to improv care.[13 ]
#
#  method : rule , statist , neural networks[edit ]
#  in the earli day , mani languag - process system were design by symbol method , i.e. , the hand - code of a set of rule , coupl with a dictionari lookup:[14][15 ] such as by write grammar or devis heurist rule for stem .
#  more recent system base on machin - learn algorithm have mani advantag over hand - produc rule :
#
#  the learn procedur use dure machin learn automat focu on the most common case , wherea when write rule by hand it is often not at all obviou where the effort should be direct .
#  automat learn procedur can make use of statist infer algorithm to produc model that are robust to unfamiliar input ( e.g. contain word or structur that have not been seen befor ) and to erron input ( e.g. with misspel word or word accident omit ) . gener , handl such input grace with handwritten rule , or , more gener , creat system of handwritten rule that make soft decis , is extrem difficult , error - prone and time - consum .
#  system base on automat learn the rule can be made more accur simpli by suppli more input data . howev , system base on handwritten rule can onli be made more accur by increas the complex of the rule , which is a much more difficult task . in particular , there is a limit to the complex of system base on handwritten rule , beyond which the system becom more and more unmanag . howev , creat more data to input to machin - learn system simpli requir a correspond increas in the number of man - hour work , gener without signific increas in the complex of the annot process .
#  despit the popular of machin learn in nlp research , symbol method are still ( 2020 ) commonli use :
#
#  when the amount of train data is insuffici to success appli machin learn method , e.g. , for the machin translat of low - resourc languag such as provid by the apertium system ,
#  for preprocess in nlp pipelin , e.g. , token , or
#  for postprocess and transform the output of nlp pipelin , e.g. , for knowledg extract from syntact pars .
#  statist methods[edit ]
#  sinc the so - call " statist revolution"[16][17 ] in the late 1980 and mid-1990 , much natur languag process research ha reli heavili on machin learn . the machin - learn paradigm call instead for use statist infer to automat learn such rule through the analysi of larg corpora ( the plural form of corpu , is a set of document , possibl with human or comput annot ) of typic real - world exampl .
#  mani differ class of machin - learn algorithm have been appli to natur - languag - process task . these algorithm take as input a larg set of " featur " that are gener from the input data . increasingli , howev , research ha focus on statist model , which make soft , probabilist decis base on attach real - valu weight to each input featur ( complex - valu embeddings,[18 ] and neural network in gener have also been propos , for e.g. speech[19 ] ) . such model have the advantag that they can express the rel certainti of mani differ possibl answer rather than onli one , produc more reliabl result when such a model is includ as a compon of a larger system .
#  some of the earliest - use machin learn algorithm , such as decis tree , produc system of hard if - then rule similar to exist hand - written rule .   howev , part - of - speech tag introduc the use of hidden markov model to natur languag process , and increasingli , research ha focus on statist model , which make soft , probabilist decis base on attach real - valu weight to the featur make up the input data . the cach languag model upon which mani speech recognit system now reli are exampl of such statist model .   such model are gener more robust when given unfamiliar input , especi input that contain error ( as is veri common for real - world data ) , and produc more reliabl result when integr into a larger system compris multipl subtask .
#  sinc the neural turn , statist method in nlp research have been larg replac by neural network . howev , they continu to be relev for context in which statist interpret and transpar is requir .
#
#  neural networks[edit ]
#  further inform : artifici neural network
#  a major drawback of statist method is that they requir elabor featur engin . sinc 2015,[20 ] the field ha thu larg abandon statist method and shift to neural network for machin learn . popular techniqu includ the use of word embed to captur semant properti of word , and an increas in end - to - end learn of a higher - level task ( e.g. , question answer ) instead of reli on a pipelin of separ intermedi task ( e.g. , part - of - speech tag and depend pars ) . in some area , thi shift ha entail substanti chang in how nlp system are design , such that deep neural network - base approach may be view as a new paradigm distinct from statist natur languag process . for instanc , the term neural machin translat ( nmt ) emphas the fact that deep learn - base approach to machin translat directli learn sequenc - to - sequenc transform , obviat the need for intermedi step such as word align and languag model that wa use in statist machin translat ( smt ) .
#
#  common nlp tasks[edit ]
#  the follow is a list of some of the most commonli research task in natur languag process . some of these task have direct real - world applic , while other more commonli serv as subtask that are use to aid in solv larger task .
#  though natur languag process task are close intertwin , they can be subdivid into categori for conveni . a coars divis is given below .
#
#  text and speech processing[edit ]
#  optic charact recognit ( ocr )
#  given an imag repres print text , determin the correspond text .
#  speech recognit
#  given a sound clip of a person or peopl speak , determin the textual represent of the speech .   thi is the opposit of text to speech and is one of the extrem difficult problem colloqui term " ai - complet " ( see abov ) .   in natur speech there are hardli ani paus between success word , and thu speech segment is a necessari subtask of speech recognit ( see below ) . in most spoken languag , the sound repres success letter blend into each other in a process term coarticul , so the convers of the analog signal to discret charact can be a veri difficult process . also , given that word in the same languag are spoken by peopl with differ accent , the speech recognit softwar must be abl to recogn the wide varieti of input as be ident to each other in term of it textual equival .
#  speech segment
#  given a sound clip of a person or peopl speak , separ it into word .   a subtask of speech recognit and typic group with it .
#  text - to - speech
#  given a text , transform those unit and produc a spoken represent . text - to - speech can be use to aid the visual impaired.[21 ]
#  word segment ( token )
#  separ a chunk of continu text into separ word . for a languag like english , thi is fairli trivial , sinc word are usual separ by space . howev , some written languag like chines , japanes and thai do not mark word boundari in such a fashion , and in those languag text segment is a signific task requir knowledg of the vocabulari and morpholog of word in the languag . sometim thi process is also use in case like bag of word ( bow ) creation in data mine .
#  morpholog analysis[edit ]
#  lemmat
#  the task of remov inflect end onli and to return the base dictionari form of a word which is also known as a lemma . lemmat is anoth techniqu for reduc word to their normal form . but in thi case , the transform actual use a dictionari to map word to their actual form.[22 ]
#  morpholog segment
# ...
#
#  ^ " ask the cognit scientist " . american feder of teacher . 8 august 2014 . cognit scienc is an interdisciplinari field of research from linguist , psycholog , neurosci , philosophi , comput scienc , and anthropolog that seek to understand the mind .
#
#  ^ robinson , peter ( 2008 ) . handbook of cognit linguist and second languag acquisit . routledg . pp .   3–8 . isbn   978 - 0 - 805 - 85352 - 0 .
#
#  ^ lakoff , georg ( 1999 ) . philosophi in the flesh : the embodi mind and it challeng to western philosophi ; appendix : the neural theori of languag paradigm . new york basic book . pp .   569–583 . isbn   978 - 0 - 465 - 05674 - 3 .
#
#  ^ strauss , claudia ( 1999 ) . a cognit theori of cultur mean . cambridg univers press . pp .   156–164 . isbn   978 - 0 - 521 - 59541 - 4 .
#
#  ^ " univers conceptu cognit annot ( ucca ) " . univers conceptu cognit annot ( ucca ) . retriev 2021 - 01 - 11 .
#
#  ^ rodríguez , f. c. , & mairal - usón , r. ( 2016 ) . build an rrg comput grammar . onomazein , ( 34 ) , 86 - 117 .
#
#  ^ " fluid construct grammar – a fulli oper process system for construct grammar " . retriev 2021 - 01 - 11 .
#
#  ^ " acl member portal | the associ for comput linguist member portal " . www.aclweb.org . retriev 2021 - 01 - 11 .
#
#  ^ " chunk and rule " . www.w3.org . retriev 2021 - 01 - 11 .
#
#  ^ socher , richard ; karpathi , andrej ; le , quoc v. ; man , christoph d. ; ng , andrew y. ( 2014 ) . " ground composit semant for find and describ imag with sentenc " . transact of the associ for comput linguist . 2 : 207–218 . doi:10.1162 / tacl_a_00177 . s2cid   2317858 .
#
#
#  further reading[edit ]
#  .mw - parser - output .refbegin{font - size:90%;margin - bottom:0.5em}.mw - parser - output .refbegin - hang - indent > ul{margin - left:0}.mw - parser - output .refbegin - hang - indent > ul > li{margin - left:0;pad - left:3.2em;text - indent:-3.2em}.mw - parser - output .refbegin - hang - indent ul,.mw - parser - output .refbegin - hang - indent ul li{list - style : none}@media(max - width:720px){.mw - parser - output .refbegin - hang - indent > ul > li{pad - left:1.6em;text - indent:-1.6em}}.mw - parser - output .refbegin - columns{margin - top:0.3em}.mw - parser - output .refbegin - column ul{margin - top:0}.mw - parser - output .refbegin - column li{pag - break - insid : avoid;break - insid : avoid - column }
#  bate , m ( 1995 ) . " model of natur languag understand " . proceed of the nation academi of scienc of the unit state of america . 92 ( 22 ): 9977–9982 . bibcode:1995pna ... 92.9977b. doi:10.1073 / pnas.92.22.9977 . pmc   40721 . pmid   7479812 .
#  steven bird , ewan klein , and edward loper ( 2009 ) . natur languag process with python . o'reilli media . isbn   978 - 0 - 596 - 51649 - 9 .
#  daniel jurafski and jame h. martin ( 2008 ) . speech and languag process , 2nd edit . pearson prentic hall . isbn   978 - 0 - 13 - 187321 - 6 .
#  moham zakaria kurdi ( 2016 ) . natur languag process and comput linguist : speech , morpholog , and syntax , volum 1 . ist - wiley . isbn   978 - 1848218482 .
#  moham zakaria kurdi ( 2017 ) . natur languag process and comput linguist : semant , discours , and applic , volum 2 . ist - wiley . isbn   978 - 1848219212 .
#  christoph d. man , prabhakar raghavan , and hinrich schütze ( 2008 ) . introduct to inform retriev . cambridg univers press . isbn   978 - 0 - 521 - 86571 - 5 . offici html and pdf version avail without charg .
#  christoph d. man and hinrich schütze ( 1999 ) . foundat of statist natur languag process . the mit press . isbn   978 - 0 - 262 - 13360 - 9 .
#  david m. w. power and christoph c. r. turk ( 1989 ) . machin learn of natur languag . springer - verlag . isbn   978 - 0 - 387 - 19557 - 5 .
#
#  extern links[edit ]
#   media relat to natur languag process at wikimedia common
#  .mw - parser - output .hlist dl,.mw - parser - output .hlist ol,.mw - parser - output .hlist ul{margin:0;padding:0}.mw - parser - output .hlist dd,.mw - parser - output .hlist dt,.mw - parser - output .hlist li{margin:0;display : inline}.mw - parser - output .hlist.inline,.mw - parser - output .hlist.inlin dl,.mw - parser - output .hlist.inlin ol,.mw - parser - output .hlist.inlin ul,.mw - parser - output .hlist dl dl,.mw - parser - output .hlist dl ol,.mw - parser - output .hlist dl ul,.mw - parser - output .hlist ol dl,.mw - parser - output .hlist ol ol,.mw - parser - output .hlist ol ul,.mw - parser - output .hlist ul dl,.mw - parser - output .hlist ul ol,.mw - parser - output .hlist ul ul{display : inline}.mw - parser - output .hlist .mw - empti - li{display : none}.mw - parser - output .hlist dt::after{cont : " : " } .mw - parser - output .hlist dd::after,.mw - parser - output .hlist li::after{cont : " · " ; font - weight : bold}.mw - parser - output .hlist dd : last - child::after,.mw - parser - output .hlist dt : last - child::after,.mw - parser - output .hlist li : last - child::after{cont : none}.mw - parser - output .hlist dd dd : first - child::before,.mw - parser - output .hlist dd dt : first - child::before,.mw - parser - output .hlist dd li : first - child::before,.mw - parser - output .hlist dt dd : first - child::before,.mw - parser - output .hlist dt dt : first - child::before,.mw - parser - output .hlist dt li : first - child::before,.mw - parser - output .hlist li dd : first - child::before,.mw - parser - output .hlist li dt : first - child::before,.mw - parser - output .hlist li li : first - child::before{cont : " ( " ; font - weight : normal}.mw - parser - output .hlist dd dd : last - child::after,.mw - parser - output .hlist dd dt : last - child::after,.mw - parser - output .hlist dd li : last - child::after,.mw - parser - output .hlist dt dd : last - child::after,.mw - parser - output .hlist dt dt : last - child::after,.mw - parser - output .hlist dt li : last - child::after,.mw - parser - output .hlist li dd : last - child::after,.mw - parser - output .hlist li dt : last - child::after,.mw - parser - output .hlist li li : last - child::after{content:")";font - weight : normal}.mw - parser - output .hlist ol{count - reset : listitem}.mw - parser - output .hlist ol > li{count - increment : listitem}.mw - parser - output .hlist ol > li::before{cont : " " counter(listitem)"\a0 " } .mw - parser - output .hlist dd ol > li : first - child::before,.mw - parser - output .hlist dt ol > li : first - child::before,.mw - parser - output .hlist li ol > li : first - child::before{cont : " ( " counter(listitem)"\a0 " } .mw - parser - output .navbox{box - size : border - box;border:1px solid # a2a9b1;width:100%;clear : both;font - size:88%;text - align : center;padding:1px;margin:1em auto 0}.mw - parser - output .navbox .navbox{margin - top:0}.mw - parser - output .navbox+.navbox,.mw - parser - output .navbox+.navbox - styles+.navbox{margin - top:-1px}.mw - parser - output .navbox - inner,.mw - parser - output .navbox - subgroup{width:100%}.mw - parser - output .navbox - group,.mw - parser - output .navbox - title,.mw - parser - output .navbox - abovebelow{padding:0.25em 1em;lin - height:1.5em;text - align : center}.mw - parser - output .navbox - group{whit - space : nowrap;text - align : right}.mw - parser - output .navbox,.mw - parser - output .navbox - subgroup{background - color:#fdfdfd}.mw - parser - output .navbox - list{lin - height:1.5em;bord - color:#fdfdfd}.mw - parser - output .navbox - list - with - group{text - align : left;bord - left - width:2px;bord - left - style : solid}.mw - parser - output tr+tr>.navbox - abovebelow,.mw - parser - output tr+tr>.navbox - group,.mw - parser - output tr+tr>.navbox - image,.mw - parser - output tr+tr>.navbox - list{bord - top:2px solid # fdfdfd}.mw - parser - output .navbox - title{background - color:#ccf}.mw - parser - output .navbox - abovebelow,.mw - parser - output  ...
#  ai - complet
#  bag - of - word
#  n - gram
#  bigram
#  trigram
#  comput linguist
#  natur - languag understand
#  stop word
#  text process
#  text analysi
#  colloc extract
#  concept mine
#  corefer resolut
#  deep linguist process
#  distant read
#  inform extract
#  name - entiti recognit
#  ontolog learn
#  pars
#  part - of - speech tag
#  semant role label
#  semant similar
#  sentiment analysi
#  terminolog extract
#  text mine
#  textual entail
#  truecas
#  word - sens disambigu
#  word - sens induct
#  text segment
#  compound - term process
#  lemmatis
#  lexic analysi
#  text chunk
#  stem
#  sentenc segment
#  word segment
#
#  automat summar
#  multi - document summar
#  sentenc extract
#  text simplif
#  machin translat
#  comput - assist
#  exampl - base
#  rule - base
#  statist
#  transfer - base
#  neural
#  distribut semant model
#  bert
#  document - term matrix
#  explicit semant analysi
#  fasttext
#  glove
#  languag model
#  latent semant analysi
#  seq2seq
#  word embed
#  word2vec
#  languag resourc , dataset and corporatyp andstandard
#  corpu linguist
#  lexic resourc
#  linguist link open data
#  machin - readabl dictionari
#  parallel text
#  propbank
#  semant network
#  simpl knowledg organ system
#  speech corpu
#  text corpu
#  thesauru ( inform retriev )
#  treebank
#  univers depend
#  data
#  babelnet
#  bank of english
#  dbpedia
#  framenet
#  googl ngram viewer
#  ubi
#  wordnet
#  automat identificationand data captur
#  speech recognit
#  speech segment
#  speech synthesi
#  natur languag gener
#  optic charact recognit
#  topic model
#  document classif
#  latent dirichlet alloc
#  pachinko alloc
#  comput - assistedreview
#  autom essay score
#  concordanc
#  grammar checker
#  predict text
#  speech verif
#  spell checker
#  syntax guess
#  natur languageus interfac
#  chatbot
#  interact fiction
#  question answer
#  virtual assist
#  voic user interfac
#  relat
#  hallucin
#  natur languag toolkit
#  spaci
#
#  .mw - parser - output .portal - bar{font - size:88%;font - weight : bold;display : flex;justifi - content : center;align - item : baseline}.mw - parser - output .portal - bar - bordered{padding:0 2em;background - color:#fdfdfd;border:1px solid # a2a9b1;clear : both;margin:1em auto 0}.mw - parser - output .portal - bar - related{font - size:100%;justifi - content : flex - start}.mw - parser - output .portal - bar - unbordered{padding:0 1.7em;margin - left:0}.mw - parser - output .portal - bar - header{margin:0 1em 0 0.5em;flex:0 0 auto;min - height:24px}.mw - parser - output .portal - bar - content{display : flex;flex - flow : row wrap;flex:0 1 auto;padding:0.15em 0;column - gap:1em;align - item : baseline;margin:0;list - style : none}.mw - parser - output .portal - bar - content - related{margin:0;list - style : none}.mw - parser - output .portal - bar - item{display : inlin - block;margin:0.15em 0.2em;min - height:24px;lin - height:24px}@media screen and ( max - width:768px){.mw - parser - output .portal - bar{font - size:88%;font - weight : bold;display : flex;flex - flow : column wrap;align - item : baseline}.mw - parser - output .portal - bar - header{text - align : center;flex:0;pad - left:0.5em;margin:0 auto}.mw - parser - output .portal - bar - related{font - size:100%;align - item : flex - start}.mw - parser - output .portal - bar - content{display : flex;flex - flow : row wrap;align - item : center;flex:0;column - gap:1em;bord - top:1px solid # a2a9b1;margin:0 auto;list - style : none}.mw - parser - output .portal - bar - content - related{bord - top : none;margin:0;list - style : none}}.mw - parser - output .navbox+link+.port - bar,.mw - parser - output .navbox+style+.port - bar,.mw - parser - output .navbox+link+.port - bar - bordered,.mw - parser - output .navbox+style+.port - bar - bordered,.mw - parser - output .sister - bar+link+.port - bar,.mw - parser - output .sister - bar+style+.port - bar,.mw - parser - output .portal - bar+.navbox - styles+.navbox,.mw - parser - output .portal - bar+.navbox - styles+.sist - bar{margin - top:-1px}port :   languag
#  .mw - parser - output .tooltip - dotted{bord - bottom:1px dotted;cursor : help}author control : nation librari
#  israel
#  unit state
#  japan
#  czech republ
#
#
#
#
#
#  retriev from " https://en.wikipedia.org/w/index.php?title=natural_language_processing&oldid=1141420081 "
#  categori : natur languag processingcomput field of studycomput linguisticsspeech recognitionhidden categori : all accuraci disputesaccuraci disput from decemb 2013cs1 maint : locationarticl with short descriptionshort descript is differ from wikidatacommon categori link from wikidataarticl with j9u identifiersarticl with lccn identifiersarticl with ndl identifiersarticl with nkc identifi
#
#
#
#
#
#
#   thi page wa last edit on 25 februari 2023 , at 00:09   ( utc ) .
#  text is avail under the creativ common attribut - sharealik licens 3.0 ;
#  addit term may appli .   by use thi site , you agre to the term of use and privaci polici . wikipedia ® is a regist trademark of the wikimedia foundat , inc. , a non - profit organ .
#
#
#  privaci polici
#  about wikipedia
#  disclaim
#  contact wikipedia
#  mobil view
#  develop
#  statist
#  cooki statement
#
#
#
#
#
#
#
#
#
#  ( rlq = window . rlq||[]).push(function(){mw.config.set({"wgpageparsereport":{"limitreport":{"cputime":"0.887","walltime":"1.120","ppvisitednodes":{"value":4945,"limit":1000000},"postexpandincludesize":{"value":126265,"limit":2097152},"templateargumentsize":{"value":3171,"limit":2097152},"expansiondepth":{"value":14,"limit":100},"expensivefunctioncount":{"value":9,"limit":500},"unstrip - depth":{"value":1,"limit":20},"unstrip - size":{"value":163974,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00 %   955.865       1 -total " , " 47.61 %   455.079       1 templat : reflist " , " 11.53 %   110.239      22 templat : cite_web " , " 10.34 %    98.820       1 templat : natural_language_process " , " 10.25 %    97.956       3 templat : navbox " , "   9.65 %    92.255       1 templat : cite_confer " , "   8.98 %    85.792      12 templat : cite_journ " , "   7.34 %    70.202       1 templat : commonscatinlin " , "   7.04 %    67.274       1 templat : sister - inlin " , "   6.37 %    60.854       1 templat : short_description"]},"scribunto":{"limitreport - timeusage":{"value":"0.540","limit":"10.000"},"limitreport - memusage":{"value":6852625,"limit":52428800}},"cachereport":{"origin":"mw1477","timestamp":"20230226192653","ttl":1814400,"transientcontent":fals } } } ) ; } ) ;
#  { " @context":"https:\/\/schema.org","@type":"article","name":"natur languag processing","url":"https:\/\/en.wikipedia.org\/wiki\/natural_language_processing","sameas":"http:\/\/www.wikidata.org\/entity\/q30642","mainentity":"http:\/\/www.wikidata.org\/entity\/q30642","author":{"@type":"organization","name":"contributor to wikimedia projects"},"publisher":{"@type":"organization","name":"wikimedia foundat , inc. ","logo":{"@type":"imageobject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf - hor - googpub.png"}},"datepublished":"2001 - 09 - 22t05:47:41z","datemodified":"2023 - 02 - 25t00:09:38z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/8b\/automated_online_assistant.png","headline":"field of comput scienc and linguistics"}{"@context":"https:\/\/schema.org","@type":"article","name":"natur languag processing","url":"https:\/\/en.wikipedia.org\/wiki\/natural_language_processing","sameas":"http:\/\/www.wikidata.org\/entity\/q30642","mainentity":"http:\/\/www.wikidata.org\/entity\/q30642","author":{"@type":"organization","name":"contributor to wikimedia projects"},"publisher":{"@type":"organization","name":"wikimedia foundat , inc. ","logo":{"@type":"imageobject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf - hor - googpub.png"}},"datepublished":"2001 - 09 - 22t05:47:41z","datemodified":"2023 - 02 - 25t00:09:38z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/8b\/automated_online_assistant.png","headline":"field of comput scienc and linguist " }
#  ( rlq = window . rlq||[]).push(function(){mw.config.set({"wgbackendresponsetime":137,"wghostname":"mw1441 " } ) ; } ) ;

# %% [markdown]
# ## Stop-Word Removal

# %%
from spacy.lang.en.stop_words import STOP_WORDS
filtered_words = [word for word in words if word.lower() not in STOP_WORDS]
print(filtered_words)
# Out:
# ['Natural', 'Language', 'Processing', 'Corpus', 'Linguistics', 'Elements', 'Corpus', 'Linguistics', 'Cambridge', 'University', 'Press', 'Jonathan', 'Dunn', 'University', 'Canterbury', 'Abstract', '.', 'Corpus', 'analysis', 'expanded', 'scaled', 'incorporating', 'computational', 'methods', 'natural', 'language', 'processing', '.', 'Element', 'shows', 'text', 'classification', 'text', 'similarity', 'models', 'extend', 'ability', 'undertake', 'corpus', 'linguistics', 'large', 'corpora', '.', 'computational', 'methods', 'coming', 'increasingly', 'important', 'corpora', 'grow', 'large', 'traditional', 'types', 'linguistic', 'analysis', '.', 'draw', 'case', 'studies', 'use', 'computational', 'methods', ',', 'ranging', 'usage', '-based', 'grammar', 'authorship', 'analysis', 'soci', 'al', 'media', 'corpus', '-based', 'sociolinguistics', '.', 'section', 'accompanied', 'interactive', 'code', 'notebook', 'shows', 'implement', 'analysis', 'Python', '.', 'stand', '-', 'Python', 'package', 'available', 'help', 'readers', 'use', 'methods', 'data', '.', 'large', '-scale', 'analysis', 'introduces', 'new', 'ethical', 'problems', ',', 'Element', 'pairs', 'new', 'methodology', 'discussion', 'potential', 'ethical', 'implications', '.', 'Book', ':', 'https://doi.org/10.1017/9781009070447', 'Interactivate', 'Notebooks', ':', 'https://doi.org/10', '.24433', '/', 'CO.3402613.v1', 'Python', 'Package', ':', 'https://github.com/jonathandunn/text_analytics', 'Table', 'Contents', '1', '.', 'Computational', 'Linguistic', 'Analysis', '1.1', '.', 'Scaling', 'Corpus', 'Linguistics', '1.2', '.', 'Case', 'Studies', '1.3', '.', 'Categorization', 'Problems', '1.4', '.', 'Comparison', 'Problems', '1.5', '.', 'Language', 'Vector', 'Space', '1.6', '.', 'Ethics', ':', 'Data', 'Rights', '2', '.', 'Text', 'Classification', '2.1', '.', 'Evaluating', 'Classifiers', '2.2', '.', 'Representing', 'Content', '2.3', '.', 'Representing', 'Structure', '2.4', '.', 'Representing', 'Context', '2.5', '.', 'Representing', 'Sentiment', '2.6', '.', 'Logistic', 'Regression', '2.7', '.', 'Feed', '-Forward', 'Networks', '2.8', '.', 'Ethics', ':', 'Implicit', 'Bias', '3', '.', 'Text', 'Similarity', '3.1', '.', 'Categorization', 'Cognition', '3.2', '.', 'Measuring', 'Corpus', 'Similarity', '3.3', '.', 'Measuring', 'Document', 'Similarity', '3.4', '.', 'Measuring', 'Word', 'Similarity', 'Association', '3.5', '.', 'Measuring', 'Word', 'Similarity', 'Vector', 'Space', '3.6', '.', 'Clustering', 'Similarit', 'y', '3.7', '.', 'Ethics', ':', 'Model', 'Discrimination', '4', '.', 'Validation', 'Visualization', '4.1', '.', 'Reporting', 'Results', 'Political', 'Speech', 'Prediction', '4.2', '.', 'Ensuring', 'Validity', 'Box', 'Plots', '4.3', '.', 'Unmasking', 'Pseudonymous', 'Authors', 'Line', 'Plots', '4.4', '.', 'Comparing', 'Word', 'Embeddings', 'Heat', 'Maps', '4.5', '.', 'Following', 'Linguistic', 'Diversity', 'Choropleth', 'Maps', '4.6', '.', 'Ethics', ':', 'Equal', 'Access', '5', '.', 'Conclusions', '1.1', 'Scaling', 'Corpus', 'Linguistics', 'Corpus', 'linguistics', 'entered', 'golden', 'age', ',', 'driven', 'range', 'language', 'available', 'linguistic', 'analysis', '.', 'Corpus', 'data', 'able', 'represent', 'population', 'usage', 'scale', ',', '-passing', 'limitations', 'introspect', 'ion', 'important', '1950s', '.', 'wide', 'availability', 'language', 'data', 'requires', 'linguists', 'methods', 'available', 'analyze', '.', 'surge', 'advances', 'natural', 'language', 'processing', 'computational', 'linguistics', ',', 'ad', 'vances', 'increasingly', 'disconnected', 'corpus', 'linguistics', 'linguistic', 'theory', '.', 'Element', 'brings', 'natural', 'language', 'processing', 'corpus', 'linguistics', ',', 'showing', 'computational', 'models', 'answer', 'categorization', 'comparison', 'problems', '.', 'computational', 'models', 'presented', 'case', 'studies', 'introduced', 'section', ',', 'ranging', 'syntactic', 'analysis', 'register', 'analysis', 'corpus', '-based', 'sociolinguistics', '.', 'go ...

# %% [markdown]
# # Hindi Language

# %% [markdown]
# ##  Scrape the Website

# %%
# !pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 8.4 MB/s eta 0:00:00
# Collecting feedparser>=5.2.1
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 8.8 MB/s eta 0:00:00
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 46.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (6.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (4.9.2)
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (3.7)
# Collecting cssselect>=0.9.2
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tldextract>=2.0.1
#   Downloading tldextract-3.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (4.6.3)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from newspaper3k) (2.25.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2.1->newspaper3k) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->newspaper3k) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->newspaper3k) (2022.12.7)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.8/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.9.0)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13552 sha256=4c8c1d32c2e39b613572fca5bf2d2d2d966e80c599c8c3c4f1282239a6a24437
#   Stored in directory: /root/.cache/pip/wheels/99/74/83/8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3354 sha256=7942b1ec2bcce81aa7fbcc1b1d9a0256be205676284f4e4f523a977a80514e1c
#   Stored in directory: /root/.cache/pip/wheels/b6/09/68/a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398405 sha256=4451548e794b3b6ce074e7db167f09b836217470b07045c193a1c9ad84a52cb5
#   Stored in directory: /root/.cache/pip/wheels/1f/7e/0c/54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=d9f0ae25d9df4aa184ed3f012d5ac134abca4c99f6c5dcd8145a6ebde6386d56
#   Stored in directory: /root/.cache/pip/wheels/83/63/2f/117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.10 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.4.0

# %%
import newspaper
from newspaper import Article

# Set the URL of the article
url = 'https://www.bhaskar.com/'

# Create an Article object
article = Article(url, language='hi')

# Download and parse the article
article.download()
article.parse()

# Get the text of the article
text = article.text

print(text)
# Out:
# शाओमी इलेक्ट्रिक स्कूटर 4 अल्ट्रा लॉन्च: चार ड्राइविंग मोड्स के साथ मिलेगी 70 किमी की रेंज; MIUI 14 हुआ लाइव! एडवांस होंगे शाओमी स्मार्टफोन्स

# %%
corpus = '''लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए दिल्ली पहुंचे, मुख्य तौर पर हैं चार मांगें
लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं.




अगस्त 2019 में जब मोदी सरकार ने जम्मू-कश्मीर से अनुच्छेद-370 हटाया तो लद्दाख को यूनियन टेरिटरी का दर्ज़ा मिला.  लद्दाख में लेह की पहाड़ियों पर रहने वाले लोगों ने नाच-गाकर इसका जश्न मनाया, लेकिन अब लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं. 
यह भी पढ़ें
जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया
जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया
लद्दाख गतिरोध के बाद भारत और चीन के बीच  बीजिंग में पहली व्‍यक्तिगत बातचीत
लद्दाख गतिरोध के बाद भारत और चीन के बीच बीजिंग में पहली व्‍यक्तिगत बातचीत
जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं
जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं
लद्दाख के लोगों की चार मांगें हैं. पहला राज्य का दर्जा, दूसरा छठी अनुसूची के तहत संवैधानिक सुरक्षा, तीसरा लेह और कारगिल जिलों के लिए अलग लोकसभा सीटें और चौथा स्थानीय लोगों के लिए नौकरी में आरक्षण.  मैगसेसे अवार्ड से सम्मानित सोनम वांगचुक भी इस प्रदर्शन में शामिल होंगे.

इन लोगों की मांग है कि लद्दाख को केंद्र शासित प्रदेश बनाया जाए, लेकिन विधानसभा के साथ. फिलहाल, लद्दाख के लोग अपने कल्चर, अपनी ज़मीन की पहचान और पर्यावरण के लिए आवाज़ उठा रहे हैं. लद्दाख से उठ रही तमाम मागों में सबसे अहम है लद्दाख को शेड्यूल-6 में शामिल करने की, जो लद्दाख में मौजूद जिला काउंसिलों को खास अधिकार देगा.

इससे इन काउंसिल के पास इलाके में ज़मीन, जंगल समेत अन्य चीजों में कानून बनाने का अधिकार होगा. शेड्यूल-6 के बिना लद्दाख की नाज़ुक पारिस्थिति उद्योगों के प्रवाह से गंभीर रूप से प्रभावित हो सकती है. भाजपा ने वादा किया था कि लद्दाख ऑटोनोमस हिल डेवलपमेंट कौंसिल के चुनाव जीतने के बाद शेड्यूल-6 पर करवाई होगी.

लोगों का आरोप है कि लद्दाख के लिए आवंटित किया गया बजट भी ठीक से इस्तेमाल नहीं किया जा रहा. बढ़ते पर्यटन को लेकर भी चिंता है. लद्दाख की जनसंख्या 3.5 लाख है, लेकिन 2020-21 में  4 लाख पर्यटक यहां पहुंचे थे, जिसे लेकर चिंता जताई गई. इस बात को लेकर गुस्सा है कि लद्दाख के लोगों की अभी भी प्रतिनिधित्व की कमी है और नीति-निर्माण में उनकी भूमिका बहुत कम है.
 '''
print(corpus)
# Out:
# लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए दिल्ली पहुंचे, मुख्य तौर पर हैं चार मांगें
# लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं. (सांकेतिक फोटो)
#
#
#
#
# अगस्त 2019 में जब मोदी सरकार ने जम्मू-कश्मीर से अनुच्छेद-370 हटाया तो लद्दाख को यूनियन टेरिटरी का दर्ज़ा मिला.  लद्दाख में लेह की पहाड़ियों पर रहने वाले लोगों ने नाच-गाकर इसका जश्न मनाया, लेकिन अब लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं.
# यह भी पढ़ें
# जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया
# जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया
# लद्दाख गतिरोध के बाद भारत और चीन के बीच  बीजिंग में पहली व्‍यक्तिगत बातचीत
# लद्दाख गतिरोध के बाद भारत और चीन के बीच बीजिंग में पहली व्‍यक्तिगत बातचीत
# जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं
# जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं
# लद्दाख के लोगों की चार मांगें हैं. पहला राज्य का दर्जा, दूसरा छठी अनुसूची के तहत संवैधानिक सुरक्षा, तीसरा लेह और कारगिल जिलों के लिए अलग लोकसभा सीटें और चौथा स्थानीय लोगों के लिए नौकरी में आरक्षण.  मैगसेसे अवार्ड से सम्मानित सोनम वांगचुक भी इस प्रदर्शन में शामिल होंगे.
#
# इन लोगों की मांग है कि लद्दाख को केंद्र शासित प्रदेश बनाया जाए, लेकिन विधानसभा के साथ. फिलहाल, लद्दाख के लोग अपने कल्चर, अपनी ज़मीन की पहचान और पर्यावरण के लिए आवाज़ उठा रहे हैं. लद्दाख से उठ रही तमाम मागों में सबसे अहम है लद्दाख को शेड्यूल-6 में शामिल करने की, जो लद्दाख में मौजूद जिला काउंसिलों को खास अधिकार देगा.
#
# इससे इन काउंसिल के पास इलाके में ज़मीन, जंगल समेत अन्य चीजों में कानून बनाने का अधिकार होगा. शेड्यूल-6 के बिना लद्दाख की नाज़ुक पारिस्थिति उद्योगों के प्रवाह से गंभीर रूप से प्रभावित हो सकती है. भाजपा ने वादा किया था कि लद्दाख ऑटोनोमस हिल डेवलपमेंट कौंसिल के चुनाव जीतने के बाद शेड्यूल-6 पर करवाई होगी.
#
# लोगों का आरोप है कि लद्दाख के लिए आवंटित किया गया बजट भी ठीक से इस्तेमाल नहीं किया जा रहा. बढ़ते पर्यटन को लेकर भी चिंता है. लद्दाख की जनसंख्या 3.5 लाख है, लेकिन 2020-21 में  4 लाख पर्यटक यहां पहुंचे थे, जिसे लेकर चिंता जताई गई. इस बात को लेकर गुस्सा है कि लद्दाख के लोगों की अभी भी प्रतिनिधित्व की कमी है और नीति-निर्माण में उनकी भूमिका बहुत कम है.

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Tokenization

# %%
import nltk
from nltk.tokenize import LineTokenizer, word_tokenize

# Line tokenization
line_tokenizer = LineTokenizer(blanklines='discard')
lines = line_tokenizer.tokenize(corpus)
print(lines)
# Word tokenization
words = [word_tokenize(line) for line in lines]
print(words)
# Out:
# ['लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए दिल्ली पहुंचे, मुख्य तौर पर हैं चार मांगें', 'लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं. (सांकेतिक फोटो)', 'अगस्त 2019 में जब मोदी सरकार ने जम्मू-कश्मीर से अनुच्छेद-370 हटाया तो लद्दाख को यूनियन टेरिटरी का दर्ज़ा मिला.  लद्दाख में लेह की पहाड़ियों पर रहने वाले लोगों ने नाच-गाकर इसका जश्न मनाया, लेकिन अब लद्दाख के लोग अपने अस्तित्व की लड़ाई के लिए प्रदर्शन कर रहे हैं और दिल्ली पहुंचे हैं. ', 'यह भी पढ़ें', 'जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया', 'जम्मू-कश्मीर और लद्दाख में फंसे हुए 275 यात्रियों को निकाला गया', 'लद्दाख गतिरोध के बाद भारत और चीन के बीच  बीजिंग में पहली व्\u200dयक्तिगत बातचीत', 'लद्दाख गतिरोध के बाद भारत और चीन के बीच बीजिंग में पहली व्\u200dयक्तिगत बातचीत', 'जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं', 'जम्मू-कश्मीर के रामबन में भूस्खलन से पांच मकान क्षतिग्रस्त, कोई हताहत नहीं', 'लद्दाख के लोगों की चार मांगें हैं. पहला राज्य का दर्जा, दूसरा छठी अनुसूची के तहत संवैधानिक सुरक्षा, तीसरा लेह और कारगिल जिलों के लिए अलग लोकसभा सीटें और चौथा स्थानीय लोगों के लिए नौकरी में आरक्षण.  मैगसेसे अवार्ड से सम्मानित सोनम वांगचुक भी इस प्रदर्शन में शामिल होंगे.', 'इन लोगों की मांग है कि लद्दाख को केंद्र शासित प्रदेश बनाया जाए, लेकिन विधानसभा के साथ. फिलहाल, लद्दाख के लोग अपने कल्चर, अपनी ज़मीन की पहचान और पर्यावरण के लिए आवाज़ उठा रहे हैं. लद्दाख से उठ रही तमाम मागों में सबसे अहम है लद्दाख को शेड्यूल-6 में शामिल करने की, जो लद्दाख में मौजूद जिला काउंसिलों को खास अधिकार देगा.', 'इससे इन काउंसिल के पास इलाके में ज़मीन, जंगल समेत अन्य चीजों में कानून बनाने का अधिकार होगा. शेड्यूल-6 के बिना लद्दाख की नाज़ुक पारिस्थिति उद्योगों के प्रवाह से गंभीर रूप से प्रभावित हो सकती है. भाजपा ने वादा किया था कि लद्दाख ऑटोनोमस हिल डेवलपमेंट कौंसिल के चुनाव जीतने के बाद शेड्यूल-6 पर करवाई होगी.', 'लोगों का आरोप है कि लद्दाख के लिए आवंटित किया गया बजट भी ठीक से इस्तेमाल नहीं किया जा रहा. बढ़ते पर्यटन को लेकर भी चिंता है. लद्दाख की जनसंख्या 3.5 लाख है, लेकिन 2020-21 में  4 लाख पर्यटक यहां पहुंचे थे, जिसे लेकर चिंता जताई गई. इस बात को लेकर गुस्सा है कि लद्दाख के लोगों की अभी भी प्रतिनिधित्व की कमी है और नीति-निर्माण में उनकी भूमिका बहुत कम है.']
# [['लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'दिल्ली', 'पहुंचे', ',', 'मुख्य', 'तौर', 'पर', 'हैं', 'चार', 'मांगें'], ['लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.', '(', 'सांकेतिक', 'फोटो', ')'], ['अगस्त', '2019', 'में', 'जब', 'मोदी', 'सरकार', 'ने', 'जम्मू-कश्मीर', 'से', 'अनुच्छेद-370', 'हटाया', 'तो', 'लद्दाख', 'को', 'यूनियन', 'टेरिटरी', 'का', 'दर्ज़ा', 'मिला', '.', 'लद्दाख', 'में', 'लेह', 'की', 'पहाड़ियों', 'पर', 'रहने', 'वाले', 'लोगों', 'ने', 'नाच-गाकर', 'इसका', 'जश्न', 'मनाया', ',', 'लेकिन', 'अब', 'लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.'], ['यह', 'भी', 'पढ़ें'], ['जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया'], ['जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया'], ['लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत'], ['लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत'], ['जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं'], ['जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं'], ['लद्दाख', 'के', 'लोगों', 'की', 'चार', 'मांगें', 'हैं', '.', 'पहला', 'राज्य', 'का', 'दर्जा', ',', 'दूसरा', 'छठी', 'अनुसूची', 'के', 'तहत', 'संवैधानिक', 'सुरक्षा', ',', 'तीसरा', 'लेह', 'और', 'कारगिल', 'जिलों', 'के', 'लिए', 'अलग', 'लोकसभा', 'सीटें', 'और', 'चौथा', 'स्थानीय', 'लोगों', 'के', 'लिए', 'नौकरी', 'में', 'आरक्षण', '.', 'मैगसेसे', 'अवार्ड', 'से', 'सम्मानित', 'सोनम', 'वांगचुक', 'भी', 'इस', 'प्रदर्शन', 'में', 'शामिल', 'होंगे', '.'], ['इन', 'लोगों', 'की', 'मांग', 'है', 'कि', 'लद्दाख', 'को', 'केंद्र', 'शासित', 'प्रदेश', 'बनाया', 'जाए', ',', 'लेकिन', 'विधानसभा', 'के', 'साथ', '.', 'फिलहाल', ',', 'लद्दाख', 'के', 'लोग', 'अपने', 'कल्चर', ',', 'अपनी', 'ज़मीन', 'की', 'पहचान', 'और', 'पर्यावरण', 'के', 'लिए', 'आवाज़', 'उठा', 'रहे', 'हैं', '.', 'लद्दाख', 'से', 'उठ', 'रही', 'तमाम', 'मागों', 'में', 'सबसे', 'अहम', 'है', 'लद्दाख', 'को', 'शेड्यूल-6', 'में', 'शामिल', 'करने', 'की', ',', 'जो', 'लद्दाख', 'में', 'मौजूद', 'जिला', 'काउंसिलों', 'को', 'खास', 'अधिकार', 'देगा', '.'], ['इससे', 'इन', 'काउंसिल', 'के', 'पास', 'इलाके', 'में', 'ज़मीन', ',', 'जंगल', 'समेत', 'अन्य', 'चीजों', 'में', 'कानून', 'बनाने', 'का', 'अधिकार', 'होगा', '.', 'शेड्यूल-6', 'के', 'बिना', 'लद्दाख', 'की', 'नाज़ुक', 'पारिस्थिति', 'उद्योगों', 'के', 'प्रवाह', 'से', 'गंभीर', 'रूप', 'से', 'प्रभावित', 'हो', 'सकती', 'है', '.', 'भाजपा', 'ने', 'वादा', 'किया', 'था', 'कि', 'लद्दाख', 'ऑटोनोमस', 'हिल', 'डेवलपमेंट', 'कौंसिल', 'के', 'चुनाव', 'जीतने', 'के', 'बाद', 'शेड्यूल-6', 'पर', 'करवाई', 'होगी', '.'], ['लोगों', 'का', 'आरोप', 'है', 'कि', 'लद्दाख', 'के', 'लिए', 'आवंटित', 'किया', 'गया', 'बजट', 'भी', 'ठीक', 'से', 'इस्तेमाल', 'नहीं', 'किया', 'जा', 'रहा', '.', 'बढ़ते', 'पर्यटन', 'को', 'लेकर', 'भी', 'चिंता', 'है', '.', 'लद्दाख', 'की', 'जनसंख्या', '3.5', 'लाख', 'है', ',', 'लेकिन', '2020-21', 'में', '4', 'लाख', 'पर्यटक', 'यहां', 'पहुंचे', 'थे', ',', 'जिसे', 'लेकर', 'चिंता', 'जताई', 'गई', '.', 'इस', 'बात', 'को', 'लेकर', 'गुस्सा', 'है', 'कि', 'लद्दाख', 'के', 'लोगों', 'की', 'अभी', 'भी', 'प्रतिनिधित्व', 'की', 'कमी', 'है', 'और', 'नीति-निर्माण', 'में', 'उनकी', 'भूमिका', 'बहुत', 'कम', 'है', '.']]

# %% [markdown]
# ## Perform Stemming using Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# Create a stemmer object
stemmer = PorterStemmer()

# Stem the words
stemmed_words = []
for line in words:
    for word in line:
        stemmed_words.append(stemmer.stem(word))

print(stemmed_words)
# Out:
# ['लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'दिल्ली', 'पहुंचे', ',', 'मुख्य', 'तौर', 'पर', 'हैं', 'चार', 'मांगें', 'लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.', '(', 'सांकेतिक', 'फोटो', ')', 'अगस्त', '2019', 'में', 'जब', 'मोदी', 'सरकार', 'ने', 'जम्मू-कश्मीर', 'से', 'अनुच्छेद-370', 'हटाया', 'तो', 'लद्दाख', 'को', 'यूनियन', 'टेरिटरी', 'का', 'दर्ज़ा', 'मिला', '.', 'लद्दाख', 'में', 'लेह', 'की', 'पहाड़ियों', 'पर', 'रहने', 'वाले', 'लोगों', 'ने', 'नाच-गाकर', 'इसका', 'जश्न', 'मनाया', ',', 'लेकिन', 'अब', 'लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.', 'यह', 'भी', 'पढ़ें', 'जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया', 'जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया', 'लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत', 'लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत', 'जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं', 'जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं', 'लद्दाख', 'के', 'लोगों', 'की', 'चार', 'मांगें', 'हैं', '.', 'पहला', 'राज्य', 'का', 'दर्जा', ',', 'दूसरा', 'छठी', 'अनुसूची', 'के', 'तहत', 'संवैधानिक', 'सुरक्षा', ',', 'तीसरा', 'लेह', 'और', 'कारगिल', 'जिलों', 'के', 'लिए', 'अलग', 'लोकसभा', 'सीटें', 'और', 'चौथा', 'स्थानीय', 'लोगों', 'के', 'लिए', 'नौकरी', 'में', 'आरक्षण', '.', 'मैगसेसे', 'अवार्ड', 'से', 'सम्मानित', 'सोनम', 'वांगचुक', 'भी', 'इस', 'प्रदर्शन', 'में', 'शामिल', 'होंगे', '.', 'इन', 'लोगों', 'की', 'मांग', 'है', 'कि', 'लद्दाख', 'को', 'केंद्र', 'शासित', 'प्रदेश', 'बनाया', 'जाए', ',', 'लेकिन', 'विधानसभा', 'के', 'साथ', '.', 'फिलहाल', ',', 'लद्दाख', 'के', 'लोग', 'अपने', 'कल्चर', ',', 'अपनी', 'ज़मीन', 'की', 'पहचान', 'और', 'पर्यावरण', 'के', 'लिए', 'आवाज़', 'उठा', 'रहे', 'हैं', '.', 'लद्दाख', 'से', 'उठ', 'रही', 'तमाम', 'मागों', 'में', 'सबसे', 'अहम', 'है', 'लद्दाख', 'को', 'शेड्यूल-6', 'में', 'शामिल', 'करने', 'की', ',', 'जो', 'लद्दाख', 'में', 'मौजूद', 'जिला', 'काउंसिलों', 'को', 'खास', 'अधिकार', 'देगा', '.', 'इससे', 'इन', 'काउंसिल', 'के', 'पास', 'इलाके', 'में', 'ज़मीन', ',', 'जंगल', 'समेत', 'अन्य', 'चीजों', 'में', 'कानून', 'बनाने', 'का', 'अधिकार', 'होगा', '.', 'शेड्यूल-6', 'के', 'बिना', 'लद्दाख', 'की', 'नाज़ुक', 'पारिस्थिति', 'उद्योगों', 'के', 'प्रवाह', 'से', 'गंभीर', 'रूप', 'से', 'प्रभावित', 'हो', 'सकती', 'है', '.', 'भाजपा', 'ने', 'वादा', 'किया', 'था', 'कि', 'लद्दाख', 'ऑटोनोमस', 'हिल', 'डेवलपमेंट', 'कौंसिल', 'के', 'चुनाव', 'जीतने', 'के', 'बाद', 'शेड्यूल-6', 'पर', 'करवाई', 'होगी', '.', 'लोगों', 'का', 'आरोप', 'है', 'कि', 'लद्दाख', 'के', 'लिए', 'आवंटित', 'किया', 'गया', 'बजट', 'भी', 'ठीक', 'से', 'इस्तेमाल', 'नहीं', 'किया', 'जा', 'रहा', '.', 'बढ़ते', 'पर्यटन', 'को', 'लेकर', 'भी', 'चिंता', 'है', '.', 'लद्दाख', 'की', 'जनसंख्या', '3.5', 'लाख', 'है', ',', 'लेकिन', '2020-21', 'में', '4', 'लाख', 'पर्यटक', 'यहां', 'पहुंचे', 'थे', ',', 'जिसे', 'लेकर', 'चिंता', 'जताई', 'गई', '.', 'इस', 'बात', 'को', 'लेकर', 'गुस्सा', 'है', 'कि', 'लद्दाख', 'के', 'लोगों', 'की', 'अभी', 'भी', 'प्रतिनिधित्व', 'की', 'कमी', 'है', 'और', 'नीति-निर्माण', 'में', 'उनकी', 'भूमिका', 'बहुत', 'कम', 'है', '.']

# %% [markdown]
# ## Lemmatization using WordNet

# %%
from nltk.stem import WordNetLemmatizer

# Create a lemmatizer object
lemmatizer = WordNetLemmatizer()

# Lemmatize the words
lemmatized_words = []
for line in words:
    for word in line:
        lemmatized_words.append(lemmatizer.lemmatize(word))
print(lemmatized_words)
# Out:
# ['लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'दिल्ली', 'पहुंचे', ',', 'मुख्य', 'तौर', 'पर', 'हैं', 'चार', 'मांगें', 'लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.', '(', 'सांकेतिक', 'फोटो', ')', 'अगस्त', '2019', 'में', 'जब', 'मोदी', 'सरकार', 'ने', 'जम्मू-कश्मीर', 'से', 'अनुच्छेद-370', 'हटाया', 'तो', 'लद्दाख', 'को', 'यूनियन', 'टेरिटरी', 'का', 'दर्ज़ा', 'मिला', '.', 'लद्दाख', 'में', 'लेह', 'की', 'पहाड़ियों', 'पर', 'रहने', 'वाले', 'लोगों', 'ने', 'नाच-गाकर', 'इसका', 'जश्न', 'मनाया', ',', 'लेकिन', 'अब', 'लद्दाख', 'के', 'लोग', 'अपने', 'अस्तित्व', 'की', 'लड़ाई', 'के', 'लिए', 'प्रदर्शन', 'कर', 'रहे', 'हैं', 'और', 'दिल्ली', 'पहुंचे', 'हैं', '.', 'यह', 'भी', 'पढ़ें', 'जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया', 'जम्मू-कश्मीर', 'और', 'लद्दाख', 'में', 'फंसे', 'हुए', '275', 'यात्रियों', 'को', 'निकाला', 'गया', 'लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत', 'लद्दाख', 'गतिरोध', 'के', 'बाद', 'भारत', 'और', 'चीन', 'के', 'बीच', 'बीजिंग', 'में', 'पहली', 'व्\u200dयक्तिगत', 'बातचीत', 'जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं', 'जम्मू-कश्मीर', 'के', 'रामबन', 'में', 'भूस्खलन', 'से', 'पांच', 'मकान', 'क्षतिग्रस्त', ',', 'कोई', 'हताहत', 'नहीं', 'लद्दाख', 'के', 'लोगों', 'की', 'चार', 'मांगें', 'हैं', '.', 'पहला', 'राज्य', 'का', 'दर्जा', ',', 'दूसरा', 'छठी', 'अनुसूची', 'के', 'तहत', 'संवैधानिक', 'सुरक्षा', ',', 'तीसरा', 'लेह', 'और', 'कारगिल', 'जिलों', 'के', 'लिए', 'अलग', 'लोकसभा', 'सीटें', 'और', 'चौथा', 'स्थानीय', 'लोगों', 'के', 'लिए', 'नौकरी', 'में', 'आरक्षण', '.', 'मैगसेसे', 'अवार्ड', 'से', 'सम्मानित', 'सोनम', 'वांगचुक', 'भी', 'इस', 'प्रदर्शन', 'में', 'शामिल', 'होंगे', '.', 'इन', 'लोगों', 'की', 'मांग', 'है', 'कि', 'लद्दाख', 'को', 'केंद्र', 'शासित', 'प्रदेश', 'बनाया', 'जाए', ',', 'लेकिन', 'विधानसभा', 'के', 'साथ', '.', 'फिलहाल', ',', 'लद्दाख', 'के', 'लोग', 'अपने', 'कल्चर', ',', 'अपनी', 'ज़मीन', 'की', 'पहचान', 'और', 'पर्यावरण', 'के', 'लिए', 'आवाज़', 'उठा', 'रहे', 'हैं', '.', 'लद्दाख', 'से', 'उठ', 'रही', 'तमाम', 'मागों', 'में', 'सबसे', 'अहम', 'है', 'लद्दाख', 'को', 'शेड्यूल-6', 'में', 'शामिल', 'करने', 'की', ',', 'जो', 'लद्दाख', 'में', 'मौजूद', 'जिला', 'काउंसिलों', 'को', 'खास', 'अधिकार', 'देगा', '.', 'इससे', 'इन', 'काउंसिल', 'के', 'पास', 'इलाके', 'में', 'ज़मीन', ',', 'जंगल', 'समेत', 'अन्य', 'चीजों', 'में', 'कानून', 'बनाने', 'का', 'अधिकार', 'होगा', '.', 'शेड्यूल-6', 'के', 'बिना', 'लद्दाख', 'की', 'नाज़ुक', 'पारिस्थिति', 'उद्योगों', 'के', 'प्रवाह', 'से', 'गंभीर', 'रूप', 'से', 'प्रभावित', 'हो', 'सकती', 'है', '.', 'भाजपा', 'ने', 'वादा', 'किया', 'था', 'कि', 'लद्दाख', 'ऑटोनोमस', 'हिल', 'डेवलपमेंट', 'कौंसिल', 'के', 'चुनाव', 'जीतने', 'के', 'बाद', 'शेड्यूल-6', 'पर', 'करवाई', 'होगी', '.', 'लोगों', 'का', 'आरोप', 'है', 'कि', 'लद्दाख', 'के', 'लिए', 'आवंटित', 'किया', 'गया', 'बजट', 'भी', 'ठीक', 'से', 'इस्तेमाल', 'नहीं', 'किया', 'जा', 'रहा', '.', 'बढ़ते', 'पर्यटन', 'को', 'लेकर', 'भी', 'चिंता', 'है', '.', 'लद्दाख', 'की', 'जनसंख्या', '3.5', 'लाख', 'है', ',', 'लेकिन', '2020-21', 'में', '4', 'लाख', 'पर्यटक', 'यहां', 'पहुंचे', 'थे', ',', 'जिसे', 'लेकर', 'चिंता', 'जताई', 'गई', '.', 'इस', 'बात', 'को', 'लेकर', 'गुस्सा', 'है', 'कि', 'लद्दाख', 'के', 'लोगों', 'की', 'अभी', 'भी', 'प्रतिनिधित्व', 'की', 'कमी', 'है', 'और', 'नीति-निर्माण', 'में', 'उनकी', 'भूमिका', 'बहुत', 'कम', 'है', '.']

# %%
words = word_tokenize(sentence)

# %% [markdown]
# ##  Remove Stop-Words using Stop-Word Corpus

# %%
from nltk.corpus import stopwords

# Load the stop-words corpus
stop_words = set(stopwords.words('hindi'))

# Remove the stop-words
clean_words = []
for line in words:
    for word in line:
        if word not in stop_words:
            clean_words.append(word)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-55-9567891a6180> in <module>
#       2
#       3 # Load the stop-words corpus
# ----> 4 stop_words = set(stopwords.words('hindi'))
#       5
#       6 # Remove the stop-words
#
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      19         return [
#      20             line
# ---> 21             for line in line_tokenize(self.raw(fileids))
#      22             if not line.startswith(ignore_lines_startswith)
#      23         ]
#
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/api.py in raw(self, fileids)
#     216         contents = []
#     217         for f in fileids:
# --> 218             with self.open(f) as fp:
#     219                 contents.append(fp.read())
#     220         return concat(contents)
#
# /usr/local/lib/python3.8/dist-packages/nltk/corpus/reader/api.py in open(self, file)
#     229         """
#     230         encoding = self.encoding(file)
# --> 231         stream = self._root.join(file).open(encoding)
#     232         return stream
#     233
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in join(self, fileid)
#     332     def join(self, fileid):
#     333         _path = os.path.join(self._path, fileid)
# --> 334         return FileSystemPathPointer(_path)
#     335
#     336     def __repr__(self):
#
# /usr/local/lib/python3.8/dist-packages/nltk/compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# /usr/local/lib/python3.8/dist-packages/nltk/data.py in __init__(self, _path)
#     310         _path = os.path.abspath(_path)
#     311         if not os.path.exists(_path):
# --> 312             raise OSError("No such file or directory: %r" % _path)
#     313         self._path = _path
#     314
#
# OSError: No such file or directory: '/root/nltk_data/corpora/stopwords/hindi'
